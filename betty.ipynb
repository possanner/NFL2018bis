# %%
def redpr(str):
    print('\x1b[31m' + str + '\x1b[0m')
    
def greenpr(str):
    print('\x1b[32m' + str + '\x1b[0m')
    
def colorpr2(str0, str1, col1, str2, col2):
    print(str0 + '\x1b[' + col1 + 'm' + str1 + '\x1b[0m', '   at  ', '\x1b[' + col2 + 'm' + str2 + '\x1b[0m')

# %%
week = 3
lastweek = week - 1
wk = str(week)
lwk = str(lastweek)

with open('schedule_2018.txt') as f:
    #passer = f.readlines()
    schedule = list(f)

with open('Week' + lwk + '/PasserRating_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    passer = list(f)
    
with open('Week' + lwk + '/PasserDEF_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    passDEF = list(f)

with open('Week' + lwk + '/sacks_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    sacks = list(f)
    
with open('Week' + lwk + '/timessacked_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    times = list(f)
    
with open('Week' + lwk + '/rushingOFF_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    rushOFF = list(f)
    
with open('Week' + lwk + '/rushingDEF_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    rushDEF = list(f)

# %%
for i in range(len(schedule)):
    if ( schedule[i][0]==wk and schedule[i][1]==' ' ) or schedule[i][0:2]==wk:
        
        team_away = schedule[i][3:29]
        team_home = schedule[i][28:]
        print('-------------------------------------------------------')
        print(team_away, '  at  ', team_home)
        for j in range(32):
            
            if team_away.lstrip() in passer[j]:
                place1 = int(passer[j][0:2])
                col1 = '30'
                if place1 <= 10:
                    col1 = '32'
                elif place1 >= 23:
                    col1 = '31'
                    
                str1 = str(place1).rjust(3) + ' (' + passer[j][-6:].rstrip().rjust(6) + ')'
               
            if team_home.lstrip().rstrip() in passer[j]:
                place2 = int(passer[j][0:2])
                col2 = '30'
                if place2 <= 10:
                    col2 = '32'
                elif place2 >= 23:
                    col2 = '31'
                    
                str2 = str(place2).rjust(3) + ' (' + passer[j][-6:].rstrip().rjust(6) + ')'
         
            if team_away.lstrip() in passDEF[j]:
                place1b = int(passDEF[j][0:2])
                col1b = '30'
                if place1b <= 10:
                    col1b = '32'
                elif place1b >= 23:
                    col1b = '31'
                    
                str1b = str(place1b).rjust(3) + ' (' + passDEF[j][-6:].rstrip().rjust(6) + ')'
               
            if team_home.lstrip().rstrip() in passDEF[j]:
                place2b = int(passDEF[j][0:2])
                col2b = '30'
                if place2b <= 10:
                    col2b = '32'
                elif place2b >= 23:
                    col2b = '31'
                    
                str2b = str(place2b).rjust(3) + ' (' + passDEF[j][-6:].rstrip().rjust(6) + ')'
        
            if team_away.lstrip() in sacks[j]:
                place3 = int(sacks[j][0:2])
                col3 = '30'
                if place3 <= 10:
                    col3 = '32'
                elif place3 >= 23:
                    col3 = '31'
                    
                str3 = str(place3).rjust(3) + ' (' + sacks[j][-3:].rstrip().rjust(6) + ')'
               
            if team_home.lstrip().rstrip() in sacks[j]:
                place4 = int(sacks[j][0:2])
                col4 = '30'
                if place4 <= 10:
                    col4 = '32'
                elif place4 >= 23:
                    col4 = '31'
                    
                str4 = str(place4).rjust(3) + ' (' + sacks[j][-3:].rstrip().rjust(6) + ')'
                
            if team_away.lstrip() in times[j]:
                place5 = int(times[j][0:2])
                col5 = '30'
                if place5 <= 10:
                    col5 = '32'
                elif place5 >= 23:
                    col5 = '31'
                    
                str5 = str(place5).rjust(3) + ' (' + times[j][-3:].rstrip().rjust(6) + ')'
               
            if team_home.lstrip().rstrip() in times[j]:
                place6 = int(times[j][0:2])
                col6 = '30'
                if place6 <= 10:
                    col6 = '32'
                elif place6 >= 23:
                    col6 = '31'
                    
                str6 = str(place6).rjust(3) + ' (' + times[j][-3:].rstrip().rjust(6) + ')'
                
            if team_away.lstrip() in rushOFF[j]:
                place7 = int(rushOFF[j][0:2])
                col7 = '30'
                if place7 <= 10:
                    col7 = '32'
                elif place7 >= 23:
                    col7 = '31'
                    
                str7 = str(place7).rjust(3) + ' (' + rushOFF[j][-4:].rstrip().rjust(6) + ')'
               
            if team_home.lstrip().rstrip() in rushOFF[j]:
                place8 = int(rushOFF[j][0:2])
                col8 = '30'
                if place8 <= 10:
                    col8 = '32'
                elif place8 >= 23:
                    col8 = '31'
                    
                str8 = str(place8).rjust(3) + ' (' + rushOFF[j][-4:].rstrip().rjust(6) + ')'
                
            if team_away.lstrip() in rushDEF[j]:
                place9 = int(rushDEF[j][0:2])
                col9 = '30'
                if place9 <= 10:
                    col9 = '32'
                elif place9 >= 23:
                    col9 = '31'
                    
                str9 = str(place9).rjust(3) + ' (' + rushDEF[j][-4:].rstrip().rjust(6) + ')'
               
            if team_home.lstrip().rstrip() in rushDEF[j]:
                place10 = int(rushDEF[j][0:2])
                col10 = '30'
                if place10 <= 10:
                    col10 = '32'
                elif place10 >= 23:
                    col10 = '31'
                    
                str10 = str(place10).rjust(3) + ' (' + rushDEF[j][-4:].rstrip().rjust(6) + ')'
          
        colorpr2('QB rating:    ', str1, col1, str2, col2)
        colorpr2('pass defense: ', str1b, col1b, str2b, col2b)
        colorpr2('sacks:        ', str3, col3, str4, col4)
        colorpr2('oline:        ', str5, col5, str6, col6)
        colorpr2('rushOFF:      ', str7, col7, str8, col8)
        colorpr2('rushDEF:      ', str9, col9, str10, col10)
    else:
        continue
# Out:
# -------------------------------------------------------
#             New York Jets    at        Cleveland Browns
#
# QB rating:     16 (  88.9)    at    29 (  70.1)
# pass defense:   5 (  67.9)    at     6 (  72.4)
# sacks:         18 (     4)    at     7 (     7)
# oline:         19 (     5)    at    30 (    10)
# rushOFF:       21 (   3.8)    at    12 (   4.2)
# rushDEF:       15 (   3.8)    at    12 (   3.8)
# -------------------------------------------------------
#        New Orleans Saints    at         Atlanta Falcons
#
# QB rating:      3 ( 123.0)    at    23 (  82.1)
# pass defense:  32 ( 133.0)    at    10 (  82.7)
# sacks:         28 (     3)    at    20 (     4)
# oline:         15 (     4)    at    14 (     4)
# rushOFF:       31 (   2.9)    at     5 (   4.9)
# rushDEF:        5 (   3.4)    at    30 (   5.2)
# -------------------------------------------------------
#       San Francisco 49ers    at      Kansas City Chiefs
#
# QB rating:     26 (  77.4)    at     2 ( 143.3)
# pass defense:  20 (  99.0)    at    24 ( 104.0)
# sacks:         16 (     5)    at    31 (     2)
# oline:         29 (     9)    at     5 (     2)
# rushOFF:        3 (   5.3)    at     9 (   4.5)
# rushDEF:       22 (   4.3)    at    23 (   4.5)
# -------------------------------------------------------
#           Oakland Raiders    at          Miami Dolphins
#
# QB rating:     17 (  88.1)    at     7 ( 104.9)
# pass defense:   8 (  79.0)    at     1 (  56.6)
# sacks:         30 (     2)    at    27 (     3)
# oline:          6 (     2)    at    16 (     5)
# rushOFF:       24 (   3.7)    at    11 (   4.3)
# rushDEF:       32 (   5.7)    at     3 (   3.3)
# -------------------------------------------------------
#           New York Giants    at          Houston Texans
#
# QB rating:     22 (  84.5)    at    21 (  84.5)
# pass defense:   9 (  79.4)    at    27 ( 110.6)
# sacks:         32 (     1)    at    24 (     3)
# oline:         27 (     8)    at    26 (     7)
# rushOFF:       26 (   3.7)    at     2 (   5.3)
# rushDEF:       29 (   5.2)    at     4 (   3.4)
# -------------------------------------------------------
#             Buffalo Bills    at       Minnesota Vikings
#
# QB rating:     32 (  40.2)    at     5 ( 108.7)
# pass defense:  31 ( 128.7)    at     7 (  74.4)
# sacks:         21 (     4)    at     5 (     7)
# oline:         31 (    11)    at    20 (     5)
# rushOFF:       22 (   3.8)    at    25 (   3.7)
# rushDEF:       11 (   3.8)    at    14 (   3.8)
# -------------------------------------------------------
#        Cincinnati Bengals    at       Carolina Panthers
#
# QB rating:      6 ( 108.5)    at    12 (  96.9)
# pass defense:  12 (  84.5)    at    22 ( 100.2)
# sacks:         13 (     6)    at     9 (     6)
# oline:          3 (     2)    at    18 (     5)
# rushOFF:       10 (   4.4)    at     1 (   5.4)
# rushDEF:        2 (   3.2)    at    28 (   4.9)
# -------------------------------------------------------
#        Indianapolis Colts    at     Philadelphia Eagles
#
# QB rating:     19 (  87.3)    at    25 (  79.7)
# pass defense:  16 (  96.4)    at    18 (  97.1)
# sacks:         14 (     5)    at    12 (     6)
# oline:         10 (     3)    at    17 (     5)
# rushOFF:       27 (   3.6)    at    16 (   4.0)
# rushDEF:       20 (   4.0)    at     1 (   2.9)
# -------------------------------------------------------
#            Denver Broncos    at        Baltimore Ravens
#
# QB rating:     27 (  73.6)    at    14 (  91.5)
# pass defense:  25 ( 108.9)    at     4 (  67.8)
# sacks:          6 (     7)    at     8 (     6)
# oline:          4 (     2)    at    25 (     6)
# rushOFF:        4 (   5.2)    at    30 (   3.3)
# rushDEF:        7 (   3.6)    at    13 (   3.8)
# -------------------------------------------------------
#         Green Bay Packers    at     Washington Redskins
#
# QB rating:      9 ( 103.5)    at    11 ( 100.1)
# pass defense:  23 ( 101.3)    at     3 (  67.0)
# sacks:         11 (     6)    at    23 (     3)
# oline:         28 (     8)    at    24 (     6)
# rushOFF:       18 (   4.0)    at    19 (   3.9)
# rushDEF:       24 (   4.6)    at    19 (   4.0)
# -------------------------------------------------------
#          Tennessee Titans    at    Jacksonville Jaguars
#
# QB rating:     30 (  69.5)    at    13 (  92.5)
# pass defense:  21 (  99.3)    at    13 (  86.5)
# sacks:         15 (     5)    at    19 (     4)
# oline:          1 (     1)    at     2 (     1)
# rushOFF:       29 (   3.4)    at     8 (   4.6)
# rushDEF:       27 (   4.9)    at    21 (   4.2)
# -------------------------------------------------------
#      Los Angeles Chargers    at        Los Angeles Rams
#
# QB rating:      4 ( 119.6)    at    10 ( 102.5)
# pass defense:  17 (  96.6)    at     2 (  58.9)
# sacks:         10 (     6)    at    29 (     2)
# oline:         12 (     3)    at    11 (     3)
# rushOFF:        7 (   4.8)    at    20 (   3.9)
# rushDEF:       17 (   3.9)    at    18 (   3.9)
# -------------------------------------------------------
#             Chicago Bears    at       Arizona Cardinals
#
# QB rating:     24 (  80.0)    at    31 (  55.6)
# pass defense:  19 (  98.4)    at    28 ( 112.9)
# sacks:          1 (    10)    at    17 (     5)
# oline:         23 (     6)    at     9 (     3)
# rushOFF:       13 (   4.2)    at    15 (   4.1)
# rushDEF:        8 (   3.6)    at     6 (   3.6)
# -------------------------------------------------------
#            Dallas Cowboys    at        Seattle Seahawks
#
# QB rating:     18 (  87.7)    at    15 (  89.3)
# pass defense:  15 (  92.6)    at    11 (  83.6)
# sacks:          2 (     9)    at    25 (     3)
# oline:         22 (     6)    at    32 (    12)
# rushOFF:        6 (   4.9)    at    28 (   3.6)
# rushDEF:       10 (   3.7)    at    16 (   3.9)
# -------------------------------------------------------
#      New England Patriots    at           Detroit Lions
#
# QB rating:      8 ( 104.1)    at    28 (  70.6)
# pass defense:  14 (  90.3)    at    30 ( 117.7)
# sacks:         26 (     3)    at     3 (     8)
# oline:         13 (     4)    at     7 (     2)
# rushOFF:       23 (   3.7)    at    14 (   4.2)
# rushDEF:       25 (   4.7)    at    31 (   5.6)
# -------------------------------------------------------
#       Pittsburgh Steelers    at    Tampa Bay Buccaneers
#
# QB rating:     20 (  86.5)    at     1 ( 151.5)
# pass defense:  26 ( 108.9)    at    29 ( 115.6)
# sacks:          4 (     8)    at    22 (     4)
# oline:         21 (     5)    at     8 (     2)
# rushOFF:       17 (   4.0)    at    32 (   2.7)
# rushDEF:       26 (   4.8)    at     9 (   3.6)

# %%
i
# Out:
# 239
