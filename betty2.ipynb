# %%
import numpy as np

# %%
def redpr(str):
    print('\x1b[31m' + str + '\x1b[0m')
    
def greenpr(str):
    print('\x1b[32m' + str + '\x1b[0m')
    
def colorpr2(str0, str1, col1, str2, col2):
    print(str0 + '\x1b[' + col1 + 'm' + str1 + '\x1b[0m', '   at  ', '\x1b[' + col2 + 'm' + str2 + '\x1b[0m')

# %%
week = 6
lastweek = week - 1
wk = str(week)
lwk = str(lastweek)

with open('schedule_2018.txt') as f:
    #passer = f.readlines()
    schedule = list(f)

with open('Week' + lwk + '/passingOFF_ydsper_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    passOFF = list(f)
    
with open('Week' + lwk + '/passingDEF_ydsper_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    passDEF = list(f)

with open('Week' + lwk + '/sacks_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    sacks = list(f)
    
with open('Week' + lwk + '/timessacked_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    times = list(f)
    
with open('Week' + lwk + '/rushingOFF_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    rushOFF = list(f)
    
with open('Week' + lwk + '/rushingDEF_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    rushDEF = list(f)

# %%
passOFF
# Out:
# ['1    Tampa Bay Buccaneers 363.3\n',
#  '2        Los Angeles Rams 337.2\n',
#  '3       Minnesota Vikings 321.4\n',
#  '4     Pittsburgh Steelers 321.0\n',
#  '5      New Orleans Saints 320.8\n',
#  '6         Oakland Raiders 316.0\n',
#  '7          Houston Texans 307.2\n',
#  '8        Baltimore Ravens 305.0\n',
#  '9         Atlanta Falcons 304.2\n',
#  '10      Green Bay Packers 299.8\n',
#  '11     Kansas City Chiefs 297.4\n',
#  '12   Jacksonville Jaguars 293.4\n',
#  '13   Los Angeles Chargers 289.6\n',
#  '14     Indianapolis Colts 283.0\n',
#  '15     Cincinnati Bengals 272.2\n',
#  '16          Detroit Lions 268.0\n',
#  '17        New York Giants 262.2\n',
#  '18         Denver Broncos 256.8\n',
#  '19    Philadelphia Eagles 253.0\n',
#  '20    Washington Redskins 245.0\n',
#  '21   New England Patriots 244.4\n',
#  '22    San Francisco 49ers 241.8\n',
#  '23       Cleveland Browns 231.4\n',
#  '24          Chicago Bears 219.5\n',
#  '25      Carolina Panthers 210.8\n',
#  '26          New York Jets 198.8\n',
#  '27       Seattle Seahawks 193.8\n',
#  '28         Miami Dolphins 192.2\n',
#  '29       Tennessee Titans 186.8\n',
#  '30         Dallas Cowboys 172.0\n',
#  '31      Arizona Cardinals 146.2\n',
#  '32          Buffalo Bills 121.8']

# %%
team_list = []
data_dict = {}

for i in range(len(passOFF)):
    
    # passing yards per game:
    team = passOFF[i][2:25].lstrip()
    team_list.append(team)
    
    val = float(passOFF[i].rstrip()[-5:])
    
    rnk = int(passOFF[i][0:2].rstrip())
    
    data_dict[team] = {}
    data_dict[team]['passOFF'] = [val, rnk]

    
for i in range(len(passOFF)):
    # passing yards allowed per game:
    team = passDEF[i][2:25].lstrip()
    
    val = float(passDEF[i].rstrip()[-5:])
    
    rnk = int(passDEF[i][0:2].rstrip())
    
    data_dict[team]['passDEF'] = [val, rnk]
    
    # sack percentage:
    team = sacks[i][2:25].lstrip()
    
    val = float(sacks[i].rstrip()[-4:])
    
    rnk = int(sacks[i][0:2].rstrip())
    
    data_dict[team]['sacks'] = [val, rnk]
    
    # times sacked percentage:
    team = times[i][2:25].lstrip()
    
    val = float(times[i].rstrip()[-4:])
    
    rnk = int(times[i][0:2].rstrip())
    
    data_dict[team]['times'] = [val, rnk]
    
    # rushing yards per game:
    team = rushOFF[i][2:25].lstrip()
    
    val = float(rushOFF[i].rstrip()[-5:])
    
    rnk = int(rushOFF[i][0:2].rstrip())
    
    data_dict[team]['rushOFF'] = [val, rnk]
    
    # rushing yards allowed per game:
    team = rushDEF[i][2:25].lstrip()
    
    val = float(rushDEF[i].rstrip()[-5:])
    
    rnk = int(rushDEF[i][0:2].rstrip())
    
    data_dict[team]['rushDEF'] = [val, rnk]
    
    
team_list = sorted(team_list)

# %%
passOFF_ar = []

for team in team_list:
    passOFF_ar.append(data_dict[team]['passOFF'][0])
    
ps = np.linspace(np.amin(passOFF_ar), np.amax(passOFF_ar), 10)
ps[0] = 0

for j in range(9):
    
    ind, = np.where(np.logical_and(passOFF_ar <= ps[j + 1], passOFF_ar > ps[j]))
    pts = 2 - j*0.5
        
    for i in ind:
        data_dict[team_list[i]]['passOFF'] =  [data_dict[team_list[i]]['passOFF'][0], pts]

# %%
passDEF_ar = []

for team in team_list:
    passDEF_ar.append(data_dict[team]['passDEF'][0])
    
ps = np.linspace(np.amin(passDEF_ar), np.amax(passDEF_ar), 10)
ps[0] = 0

for j in range(9):
    
    ind, = np.where(np.logical_and(passDEF_ar <= ps[j + 1], passDEF_ar > ps[j]))
    pts = -2 + j*0.5
        
    for i in ind:
        data_dict[team_list[i]]['passDEF'] =  [data_dict[team_list[i]]['passDEF'][0], pts]

# %%
sacks_ar = []

for team in team_list:
    sacks_ar.append(data_dict[team]['sacks'][0])
    
ps = np.linspace(np.amin(sacks_ar), np.amax(sacks_ar), 10)
ps[0] = 0

for j in range(9):
    
    ind, = np.where(np.logical_and(sacks_ar <= ps[j + 1], sacks_ar > ps[j]))
    pts = 2 - j*0.5
        
    for i in ind:
        data_dict[team_list[i]]['sacks'] =  [data_dict[team_list[i]]['sacks'][0], pts]

# %%
times_ar = []

for team in team_list:
    times_ar.append(data_dict[team]['times'][0])
    
ps = np.linspace(np.amin(times_ar), np.amax(times_ar), 10)
ps[0] = 0

for j in range(9):
    
    ind, = np.where(np.logical_and(times_ar <= ps[j + 1], times_ar > ps[j]))
    pts = -2 + j*0.5
        
    for i in ind:
        data_dict[team_list[i]]['times'] =  [data_dict[team_list[i]]['times'][0], pts]

# %%
rushOFF_ar = []

for team in team_list:
    rushOFF_ar.append(data_dict[team]['rushOFF'][0])
    
ps = np.linspace(np.amin(rushOFF_ar), np.amax(rushOFF_ar), 10)
ps[0] = 0

for j in range(9):
    
    ind, = np.where(np.logical_and(rushOFF_ar <= ps[j + 1], rushOFF_ar > ps[j]))
    pts = 2 - j*0.5
        
    for i in ind:
        data_dict[team_list[i]]['rushOFF'] =  [data_dict[team_list[i]]['rushOFF'][0], pts]

# %%
rushDEF_ar = []

for team in team_list:
    rushDEF_ar.append(data_dict[team]['rushDEF'][0])
    
ps = np.linspace(np.amin(rushDEF_ar), np.amax(rushDEF_ar), 10)
ps[0] = 0

for j in range(9):
    
    ind, = np.where(np.logical_and(rushDEF_ar <= ps[j + 1], rushDEF_ar > ps[j]))
    pts = - 2 + j*0.5
        
    for i in ind:
        data_dict[team_list[i]]['rushDEF'] =  [data_dict[team_list[i]]['rushDEF'][0], pts] 
    
print(ps)
data_dict
# Out:
# [   0.           73.08888889   82.17777778   91.26666667  100.35555556
#   109.44444444  118.53333333  127.62222222  136.71111111  145.8       ]
# {'Tampa Bay Buccaneers': {'passOFF': [363.3, -2.0],
#   'rushDEF': [87.8, -1.0],
#   'times': [5.7, -1.0],
#   'sacks': [4.8, 1.5],
#   'rushOFF': [69.5, 2.0],
#   'passDEF': [358.0, 2.0]},
#  'Los Angeles Rams': {'passOFF': [337.2, -2.0],
#   'times': [3.5, -2.0],
#   'rushOFF': [131.2, -1.0],
#   'passDEF': [234.6, -1.0],
#   'rushDEF': [106.8, 0.0],
#   'sacks': [5.6, 1.0]},
#  'Minnesota Vikings': {'passOFF': [321.4, -1.5],
#   'sacks': [7.8, 0.0],
#   'rushDEF': [99.4, -0.5],
#   'times': [5.8, -1.0],
#   'passDEF': [278.6, 0.0],
#   'rushOFF': [65.8, 2.0]},
#  'Pittsburgh Steelers': {'passOFF': [321.0, -1.5],
#   'sacks': [8.5, -0.5],
#   'times': [4.0, -2.0],
#   'rushDEF': [105.0, 0.0],
#   'rushOFF': [84.0, 1.5],
#   'passDEF': [296.2, 0.5]},
#  'New Orleans Saints': {'passOFF': [320.8, -1.5],
#   'rushDEF': [71.4, -2.0],
#   'times': [4.0, -2.0],
#   'sacks': [6.5, 0.5],
#   'rushOFF': [103.2, 0.5],
#   'passDEF': [297.6, 0.5]},
#  'Oakland Raiders': {'passOFF': [316.0, -1.5],
#   'times': [5.2, -1.5],
#   'passDEF': [277.2, 0.0],
#   'rushOFF': [95.2, 0.5],
#   'rushDEF': [127.2, 1.0],
#   'sacks': [3.6, 2.0]},
#  'Houston Texans': {'passOFF': [307.2, -1.0],
#   'rushDEF': [95.0, -0.5],
#   'rushOFF': [116.2, -0.5],
#   'sacks': [6.7, 0.5],
#   'passDEF': [269.2, 0.0],
#   'times': [8.6, 0.0]},
#  'Baltimore Ravens': {'passOFF': [305.0, -1.0],
#   'passDEF': [215.4, -1.5],
#   'rushDEF': [88.4, -1.0],
#   'sacks': [7.0, 0.5],
#   'times': [4.9, -1.5],
#   'rushOFF': [94.4, 0.5]},
#  'Atlanta Falcons': {'passOFF': [304.2, -1.0],
#   'passDEF': [277.2, 0.0],
#   'rushDEF': [121.4, 1.0],
#   'times': [7.8, 0.0],
#   'rushOFF': [89.2, 1.0],
#   'sacks': [3.9, 2.0]},
#  'Green Bay Packers': {'passOFF': [299.8, -1.0],
#   'passDEF': [208.8, -2.0],
#   'sacks': [9.0, -1.0],
#   'rushDEF': [105.0, 0.0],
#   'rushOFF': [101.2, 0.5],
#   'times': [7.7, -0.5]},
#  'Kansas City Chiefs': {'passOFF': [297.4, -1.0],
#   'times': [3.3, -2.0],
#   'rushOFF': [115.6, -0.5],
#   'sacks': [6.0, 1.0],
#   'rushDEF': [118.8, 1.0],
#   'passDEF': [343.0, 2.0]},
#  'Jacksonville Jaguars': {'passOFF': [293.4, -1.0],
#   'passDEF': [191.0, -2.0],
#   'times': [5.0, -1.5],
#   'sacks': [6.3, 0.5],
#   'rushDEF': [101.2, 0.0],
#   'rushOFF': [111.0, 0.0]},
#  'Los Angeles Chargers': {'passOFF': [289.6, -1.0],
#   'times': [3.9, -2.0],
#   'rushDEF': [95.6, -0.5],
#   'rushOFF': [115.6, -0.5],
#   'sacks': [6.2, 0.5],
#   'passDEF': [270.2, 0.0]},
#  'Indianapolis Colts': {'passOFF': [283.0, -1.0],
#   'times': [3.9, -2.0],
#   'sacks': [7.9, 0.0],
#   'rushDEF': [106.8, 0.0],
#   'passDEF': [282.6, 0.0],
#   'rushOFF': [74.4, 2.0]},
#  'Cincinnati Bengals': {'passOFF': [272.2, -0.5],
#   'times': [4.6, -1.5],
#   'passDEF': [276.6, 0.0],
#   'sacks': [5.9, 1.0],
#   'rushOFF': [95.4, 0.5],
#   'rushDEF': [118.2, 0.5]},
#  'Detroit Lions': {'passOFF': [268.0, -0.5],
#   'sacks': [10.1, -1.5],
#   'passDEF': [222.0, -1.5],
#   'times': [4.4, -1.5],
#   'rushOFF': [97.2, 0.5],
#   'rushDEF': [145.8, 2.0]},
#  'New York Giants': {'passOFF': [262.2, -0.5],
#   'passDEF': [229.4, -1.0],
#   'times': [7.8, 0.0],
#   'rushDEF': [124.4, 1.0],
#   'rushOFF': [75.6, 1.5],
#   'sacks': [3.5, 2.0]},
#  'Denver Broncos': {'passOFF': [256.8, -0.5],
#   'rushOFF': [137.0, -1.5],
#   'passDEF': [256.2, -0.5],
#   'sacks': [6.0, 1.0],
#   'times': [6.3, -1.0],
#   'rushDEF': [139.6, 2.0]},
#  'Philadelphia Eagles': {'passOFF': [253.0, 0.0],
#   'rushDEF': [66.4, -2.0],
#   'rushOFF': [110.8, 0.0],
#   'passDEF': [276.8, 0.0],
#   'times': [7.7, -0.5],
#   'sacks': [5.7, 1.0]},
#  'Washington Redskins': {'passOFF': [245.0, 0.0],
#   'rushDEF': [92.5, -0.5],
#   'passDEF': [227.8, -1.5],
#   'rushOFF': [113.0, 0.0],
#   'sacks': [6.1, 1.0],
#   'times': [6.3, -1.0]},
#  'New England Patriots': {'passOFF': [244.4, 0.0],
#   'times': [3.2, -2.0],
#   'rushOFF': [113.0, 0.0],
#   'passDEF': [252.0, -0.5],
#   'rushDEF': [114.0, 0.5],
#   'sacks': [3.4, 2.0]},
#  'San Francisco 49ers': {'passOFF': [241.8, 0.0],
#   'rushOFF': [136.2, -1.5],
#   'rushDEF': [94.6, -0.5],
#   'passDEF': [253.8, -0.5],
#   'sacks': [4.5, 1.5],
#   'times': [9.1, 0.5]},
#  'Cleveland Browns': {'passOFF': [231.4, 0.0],
#   'rushOFF': [144.6, -2.0],
#   'sacks': [5.9, 1.0],
#   'rushDEF': [116.6, 0.5],
#   'passDEF': [281.4, 0.0],
#   'times': [9.9, 0.5]},
#  'Chicago Bears': {'passOFF': [219.5, 0.5],
#   'sacks': [11.6, -2.0],
#   'rushDEF': [64.0, -2.0],
#   'passDEF': [230.5, -1.0],
#   'rushOFF': [121.5, -0.5],
#   'times': [7.1, -0.5]},
#  'Carolina Panthers': {'passOFF': [210.8, 0.5],
#   'rushOFF': [154.0, -2.0],
#   'rushDEF': [95.0, -0.5],
#   'times': [5.1, -1.5],
#   'sacks': [6.0, 1.0],
#   'passDEF': [280.5, 0.0]},
#  'New York Jets': {'passOFF': [198.8, 1.0],
#   'rushOFF': [135.0, -1.5],
#   'sacks': [6.5, 0.5],
#   'passDEF': [266.6, 0.0],
#   'rushDEF': [105.0, 0.0],
#   'times': [6.9, -0.5]},
#  'Seattle Seahawks': {'passOFF': [193.8, 1.0],
#   'passDEF': [226.0, -1.5],
#   'rushOFF': [122.4, -0.5],
#   'sacks': [5.7, 1.0],
#   'rushDEF': [129.0, 1.5],
#   'times': [11.3, 1.5]},
#  'Miami Dolphins': {'passOFF': [192.2, 1.0],
#   'passDEF': [273.6, 0.0],
#   'rushDEF': [109.0, 0.0],
#   'times': [7.5, -0.5],
#   'rushOFF': [96.0, 0.5],
#   'sacks': [4.2, 2.0]},
#  'Tennessee Titans': {'passOFF': [186.8, 1.0],
#   'passDEF': [210.0, -1.5],
#   'sacks': [7.3, 0.0],
#   'times': [5.7, -1.0],
#   'rushOFF': [107.2, 0.0],
#   'rushDEF': [123.2, 1.0]},
#  'Dallas Cowboys': {'passOFF': [172.0, 1.5],
#   'sacks': [8.1, -0.5],
#   'rushOFF': [135.8, -1.5],
#   'rushDEF': [95.8, -0.5],
#   'passDEF': [241.6, -1.0],
#   'times': [10.0, 0.5]},
#  'Arizona Cardinals': {'passOFF': [146.2, 2.0],
#   'sacks': [7.3, 0.0],
#   'passDEF': [248.6, -0.5],
#   'times': [6.1, -1.0],
#   'rushDEF': [142.4, 2.0],
#   'rushOFF': [64.6, 2.0]},
#  'Buffalo Bills': {'passOFF': [121.8, 2.0],
#   'passDEF': [234.6, -1.0],
#   'rushDEF': [96.2, -0.5],
#   'sacks': [6.1, 1.0],
#   'rushOFF': [99.4, 0.5],
#   'times': [13.5, 2.0]}}

# %%
total_list = []

for team in team_list:
    data_dict[team]['total'] = (data_dict[team]['passOFF'][1]
    + data_dict[team]['passDEF'][1]
    + data_dict[team]['sacks'][1]
    + data_dict[team]['times'][1]
    + data_dict[team]['rushOFF'][1]
    + data_dict[team]['rushDEF'][1])
    
    total_list.append([data_dict[team]['total'], team])

# %%
power_rankings = sorted(total_list)
print('Power rankings:')
print()
for i in range(32):
    print('{:2d}'.format(i + 1), power_rankings[i][1].rjust(22), '{0:+.1f}'.format(power_rankings[i][0] ))
# Out:
# Power rankings:
#
#  1          Chicago Bears -5.5
#  2       Los Angeles Rams -5.0
#  3       Baltimore Ravens -4.0
#  4      Green Bay Packers -4.0
#  5   Jacksonville Jaguars -4.0
#  6     New Orleans Saints -4.0
#  7   Los Angeles Chargers -3.5
#  8      Carolina Panthers -2.5
#  9          Detroit Lions -2.5
# 10    Pittsburgh Steelers -2.0
# 11    Washington Redskins -2.0
# 12         Dallas Cowboys -1.5
# 13         Houston Texans -1.5
# 14    Philadelphia Eagles -1.5
# 15     Indianapolis Colts -1.0
# 16      Minnesota Vikings -1.0
# 17         Denver Broncos -0.5
# 18          New York Jets -0.5
# 19    San Francisco 49ers -0.5
# 20       Tennessee Titans -0.5
# 21     Cincinnati Bengals +0.0
# 22       Cleveland Browns +0.0
# 23   New England Patriots +0.0
# 24     Kansas City Chiefs +0.5
# 25        Oakland Raiders +0.5
# 26   Tampa Bay Buccaneers +1.5
# 27        Atlanta Falcons +3.0
# 28         Miami Dolphins +3.0
# 29        New York Giants +3.0
# 30       Seattle Seahawks +3.0
# 31          Buffalo Bills +4.0
# 32      Arizona Cardinals +4.5

# %%
for i in range(len(schedule)):
    if ( schedule[i][0]==wk and schedule[i][1]==' ' ) or schedule[i][0:2]==wk:
        
        team_away = schedule[i][3:29].lstrip().rstrip()
        team_home = schedule[i][28:].lstrip().rstrip()
        
        spread =  2.5 + data_dict[team_away]['total'] - data_dict[team_home]['total']
        
        print(team_away.rjust(22) + ' {0:+.1f}   at   '.format(spread) + team_home )
# Out:
#    Philadelphia Eagles -2.0   at   New York Giants
#       Seattle Seahawks +5.0   at   Oakland Raiders
#      Arizona Cardinals +8.0   at   Minnesota Vikings
#          Chicago Bears -6.0   at   Miami Dolphins
#   Tampa Bay Buccaneers +1.0   at   Atlanta Falcons
#   Los Angeles Chargers -1.0   at   Cleveland Browns
#          Buffalo Bills +8.0   at   Houston Texans
#    Pittsburgh Steelers +0.5   at   Cincinnati Bengals
#      Carolina Panthers +2.0   at   Washington Redskins
#     Indianapolis Colts +2.0   at   New York Jets
#       Los Angeles Rams -2.0   at   Denver Broncos
#       Baltimore Ravens -1.0   at   Tennessee Titans
#   Jacksonville Jaguars +0.0   at   Dallas Cowboys
#     Kansas City Chiefs +3.0   at   New England Patriots
#    San Francisco 49ers +6.0   at   Green Bay Packers

# %%
div_list = []
team = 'Miami Dolphins'
div_list.append([data_dict[team]['total'], team])
team = 'New England Patriots'
div_list.append([data_dict[team]['total'], team])
team = 'New York Jets'
div_list.append([data_dict[team]['total'], team])
team = 'Buffalo Bills'
div_list.append([data_dict[team]['total'], team])
AFC_east = sorted(div_list)
for i in range(4):
    print(AFC_east[i][1].rjust(22), AFC_east[i][0])
# Out:
#          New York Jets -0.5
#   New England Patriots 0.0
#         Miami Dolphins 3.0
#          Buffalo Bills 4.0

# %%
div_list = []
team = 'Cincinnati Bengals'
div_list.append([data_dict[team]['total'], team])
team = 'Baltimore Ravens'
div_list.append([data_dict[team]['total'], team])
team = 'Pittsburgh Steelers'
div_list.append([data_dict[team]['total'], team])
team = 'Cleveland Browns'
div_list.append([data_dict[team]['total'], team])
AFC_north = sorted(div_list)
for i in range(4):
    print(AFC_north[i][1].rjust(22), AFC_north[i][0])
# Out:
#       Baltimore Ravens -4.0
#    Pittsburgh Steelers -2.0
#     Cincinnati Bengals 0.0
#       Cleveland Browns 0.0

# %%
div_list = []
team = 'Tennessee Titans'
div_list.append([data_dict[team]['total'], team])
team = 'Jacksonville Jaguars'
div_list.append([data_dict[team]['total'], team])
team = 'Indianapolis Colts'
div_list.append([data_dict[team]['total'], team])
team = 'Houston Texans'
div_list.append([data_dict[team]['total'], team])
AFC_south = sorted(div_list)
for i in range(4):
    print(AFC_south[i][1].rjust(22), AFC_south[i][0])
# Out:
#   Jacksonville Jaguars -4.0
#         Houston Texans -1.5
#     Indianapolis Colts -1.0
#       Tennessee Titans -0.5

# %%
div_list = []
team = 'Kansas City Chiefs'
div_list.append([data_dict[team]['total'], team])
team = 'Denver Broncos'
div_list.append([data_dict[team]['total'], team])
team = 'Los Angeles Chargers'
div_list.append([data_dict[team]['total'], team])
team = 'Oakland Raiders'
div_list.append([data_dict[team]['total'], team])
AFC_west = sorted(div_list)
for i in range(4):
    print(AFC_west[i][1].rjust(22), AFC_west[i][0])
# Out:
#   Los Angeles Chargers -3.5
#         Denver Broncos -0.5
#     Kansas City Chiefs 0.5
#        Oakland Raiders 0.5

# %%
div_list = []
team = 'Washington Redskins'
div_list.append([data_dict[team]['total'], team])
team = 'Philadelphia Eagles'
div_list.append([data_dict[team]['total'], team])
team = 'New York Giants'
div_list.append([data_dict[team]['total'], team])
team = 'Dallas Cowboys'
div_list.append([data_dict[team]['total'], team])
NFC_east = sorted(div_list)
for i in range(4):
    print(NFC_east[i][1].rjust(22), NFC_east[i][0])
# Out:
#    Washington Redskins -2.0
#         Dallas Cowboys -1.5
#    Philadelphia Eagles -1.5
#        New York Giants 3.0

# %%
div_list = []
team = 'Chicago Bears'
div_list.append([data_dict[team]['total'], team])
team = 'Green Bay Packers'
div_list.append([data_dict[team]['total'], team])
team = 'Detroit Lions'
div_list.append([data_dict[team]['total'], team])
team = 'Minnesota Vikings'
div_list.append([data_dict[team]['total'], team])
NFC_north = sorted(div_list)
for i in range(4):
    print(NFC_north[i][1].rjust(22), NFC_north[i][0])
# Out:
#          Chicago Bears -5.5
#      Green Bay Packers -4.0
#          Detroit Lions -2.5
#      Minnesota Vikings -1.0

# %%
div_list = []
team = 'New Orleans Saints'
div_list.append([data_dict[team]['total'], team])
team = 'Tampa Bay Buccaneers'
div_list.append([data_dict[team]['total'], team])
team = 'Atlanta Falcons'
div_list.append([data_dict[team]['total'], team])
team = 'Carolina Panthers'
div_list.append([data_dict[team]['total'], team])
NFC_south = sorted(div_list)
for i in range(4):
    print(NFC_south[i][1].rjust(22), NFC_south[i][0])
# Out:
#     New Orleans Saints -4.0
#      Carolina Panthers -2.5
#   Tampa Bay Buccaneers 1.5
#        Atlanta Falcons 3.0

# %%
div_list = []
team = 'Los Angeles Rams'
div_list.append([data_dict[team]['total'], team])
team = 'Seattle Seahawks'
div_list.append([data_dict[team]['total'], team])
team = 'Arizona Cardinals'
div_list.append([data_dict[team]['total'], team])
team = 'San Francisco 49ers'
div_list.append([data_dict[team]['total'], team])
NFC_west = sorted(div_list)
for i in range(4):
    print(NFC_west[i][1].rjust(22), NFC_west[i][0])
# Out:
#       Los Angeles Rams -5.0
#    San Francisco 49ers -0.5
#       Seattle Seahawks 3.0
#      Arizona Cardinals 4.5

# %%
data_dict
# Out:
# {'Tampa Bay Buccaneers': {'passOFF': [363.3, -2.0],
#   'rushDEF': [87.8, -1.0],
#   'times': [5.7, -1.0],
#   'sacks': [4.8, 1.5],
#   'rushOFF': [69.5, 2.0],
#   'passDEF': [358.0, 2.0],
#   'total': 1.5},
#  'Los Angeles Rams': {'passOFF': [337.2, -2.0],
#   'times': [3.5, -2.0],
#   'rushOFF': [131.2, -1.0],
#   'passDEF': [234.6, -1.0],
#   'rushDEF': [106.8, 0.0],
#   'sacks': [5.6, 1.0],
#   'total': -5.0},
#  'Minnesota Vikings': {'passOFF': [321.4, -1.5],
#   'sacks': [7.8, 0.0],
#   'rushDEF': [99.4, -0.5],
#   'times': [5.8, -1.0],
#   'passDEF': [278.6, 0.0],
#   'rushOFF': [65.8, 2.0],
#   'total': -1.0},
#  'Pittsburgh Steelers': {'passOFF': [321.0, -1.5],
#   'sacks': [8.5, -0.5],
#   'times': [4.0, -2.0],
#   'rushDEF': [105.0, 0.0],
#   'rushOFF': [84.0, 1.5],
#   'passDEF': [296.2, 0.5],
#   'total': -2.0},
#  'New Orleans Saints': {'passOFF': [320.8, -1.5],
#   'rushDEF': [71.4, -2.0],
#   'times': [4.0, -2.0],
#   'sacks': [6.5, 0.5],
#   'rushOFF': [103.2, 0.5],
#   'passDEF': [297.6, 0.5],
#   'total': -4.0},
#  'Oakland Raiders': {'passOFF': [316.0, -1.5],
#   'times': [5.2, -1.5],
#   'passDEF': [277.2, 0.0],
#   'rushOFF': [95.2, 0.5],
#   'rushDEF': [127.2, 1.0],
#   'sacks': [3.6, 2.0],
#   'total': 0.5},
#  'Houston Texans': {'passOFF': [307.2, -1.0],
#   'rushDEF': [95.0, -0.5],
#   'rushOFF': [116.2, -0.5],
#   'sacks': [6.7, 0.5],
#   'passDEF': [269.2, 0.0],
#   'times': [8.6, 0.0],
#   'total': -1.5},
#  'Baltimore Ravens': {'passOFF': [305.0, -1.0],
#   'passDEF': [215.4, -1.5],
#   'rushDEF': [88.4, -1.0],
#   'sacks': [7.0, 0.5],
#   'times': [4.9, -1.5],
#   'rushOFF': [94.4, 0.5],
#   'total': -4.0},
#  'Atlanta Falcons': {'passOFF': [304.2, -1.0],
#   'passDEF': [277.2, 0.0],
#   'rushDEF': [121.4, 1.0],
#   'times': [7.8, 0.0],
#   'rushOFF': [89.2, 1.0],
#   'sacks': [3.9, 2.0],
#   'total': 3.0},
#  'Green Bay Packers': {'passOFF': [299.8, -1.0],
#   'passDEF': [208.8, -2.0],
#   'sacks': [9.0, -1.0],
#   'rushDEF': [105.0, 0.0],
#   'rushOFF': [101.2, 0.5],
#   'times': [7.7, -0.5],
#   'total': -4.0},
#  'Kansas City Chiefs': {'passOFF': [297.4, -1.0],
#   'times': [3.3, -2.0],
#   'rushOFF': [115.6, -0.5],
#   'sacks': [6.0, 1.0],
#   'rushDEF': [118.8, 1.0],
#   'passDEF': [343.0, 2.0],
#   'total': 0.5},
#  'Jacksonville Jaguars': {'passOFF': [293.4, -1.0],
#   'passDEF': [191.0, -2.0],
#   'times': [5.0, -1.5],
#   'sacks': [6.3, 0.5],
#   'rushDEF': [101.2, 0.0],
#   'rushOFF': [111.0, 0.0],
#   'total': -4.0},
#  'Los Angeles Chargers': {'passOFF': [289.6, -1.0],
#   'times': [3.9, -2.0],
#   'rushDEF': [95.6, -0.5],
#   'rushOFF': [115.6, -0.5],
#   'sacks': [6.2, 0.5],
#   'passDEF': [270.2, 0.0],
#   'total': -3.5},
#  'Indianapolis Colts': {'passOFF': [283.0, -1.0],
#   'times': [3.9, -2.0],
#   'sacks': [7.9, 0.0],
#   'rushDEF': [106.8, 0.0],
#   'passDEF': [282.6, 0.0],
#   'rushOFF': [74.4, 2.0],
#   'total': -1.0},
#  'Cincinnati Bengals': {'passOFF': [272.2, -0.5],
#   'times': [4.6, -1.5],
#   'passDEF': [276.6, 0.0],
#   'sacks': [5.9, 1.0],
#   'rushOFF': [95.4, 0.5],
#   'rushDEF': [118.2, 0.5],
#   'total': 0.0},
#  'Detroit Lions': {'passOFF': [268.0, -0.5],
#   'sacks': [10.1, -1.5],
#   'passDEF': [222.0, -1.5],
#   'times': [4.4, -1.5],
#   'rushOFF': [97.2, 0.5],
#   'rushDEF': [145.8, 2.0],
#   'total': -2.5},
#  'New York Giants': {'passOFF': [262.2, -0.5],
#   'passDEF': [229.4, -1.0],
#   'times': [7.8, 0.0],
#   'rushDEF': [124.4, 1.0],
#   'rushOFF': [75.6, 1.5],
#   'sacks': [3.5, 2.0],
#   'total': 3.0},
#  'Denver Broncos': {'passOFF': [256.8, -0.5],
#   'rushOFF': [137.0, -1.5],
#   'passDEF': [256.2, -0.5],
#   'sacks': [6.0, 1.0],
#   'times': [6.3, -1.0],
#   'rushDEF': [139.6, 2.0],
#   'total': -0.5},
#  'Philadelphia Eagles': {'passOFF': [253.0, 0.0],
#   'rushDEF': [66.4, -2.0],
#   'rushOFF': [110.8, 0.0],
#   'passDEF': [276.8, 0.0],
#   'times': [7.7, -0.5],
#   'sacks': [5.7, 1.0],
#   'total': -1.5},
#  'Washington Redskins': {'passOFF': [245.0, 0.0],
#   'rushDEF': [92.5, -0.5],
#   'passDEF': [227.8, -1.5],
#   'rushOFF': [113.0, 0.0],
#   'sacks': [6.1, 1.0],
#   'times': [6.3, -1.0],
#   'total': -2.0},
#  'New England Patriots': {'passOFF': [244.4, 0.0],
#   'times': [3.2, -2.0],
#   'rushOFF': [113.0, 0.0],
#   'passDEF': [252.0, -0.5],
#   'rushDEF': [114.0, 0.5],
#   'sacks': [3.4, 2.0],
#   'total': 0.0},
#  'San Francisco 49ers': {'passOFF': [241.8, 0.0],
#   'rushOFF': [136.2, -1.5],
#   'rushDEF': [94.6, -0.5],
#   'passDEF': [253.8, -0.5],
#   'sacks': [4.5, 1.5],
#   'times': [9.1, 0.5],
#   'total': -0.5},
#  'Cleveland Browns': {'passOFF': [231.4, 0.0],
#   'rushOFF': [144.6, -2.0],
#   'sacks': [5.9, 1.0],
#   'rushDEF': [116.6, 0.5],
#   'passDEF': [281.4, 0.0],
#   'times': [9.9, 0.5],
#   'total': 0.0},
#  'Chicago Bears': {'passOFF': [219.5, 0.5],
#   'sacks': [11.6, -2.0],
#   'rushDEF': [64.0, -2.0],
#   'passDEF': [230.5, -1.0],
#   'rushOFF': [121.5, -0.5],
#   'times': [7.1, -0.5],
#   'total': -5.5},
#  'Carolina Panthers': {'passOFF': [210.8, 0.5],
#   'rushOFF': [154.0, -2.0],
#   'rushDEF': [95.0, -0.5],
#   'times': [5.1, -1.5],
#   'sacks': [6.0, 1.0],
#   'passDEF': [280.5, 0.0],
#   'total': -2.5},
#  'New York Jets': {'passOFF': [198.8, 1.0],
#   'rushOFF': [135.0, -1.5],
#   'sacks': [6.5, 0.5],
#   'passDEF': [266.6, 0.0],
#   'rushDEF': [105.0, 0.0],
#   'times': [6.9, -0.5],
#   'total': -0.5},
#  'Seattle Seahawks': {'passOFF': [193.8, 1.0],
#   'passDEF': [226.0, -1.5],
#   'rushOFF': [122.4, -0.5],
#   'sacks': [5.7, 1.0],
#   'rushDEF': [129.0, 1.5],
#   'times': [11.3, 1.5],
#   'total': 3.0},
#  'Miami Dolphins': {'passOFF': [192.2, 1.0],
#   'passDEF': [273.6, 0.0],
#   'rushDEF': [109.0, 0.0],
#   'times': [7.5, -0.5],
#   'rushOFF': [96.0, 0.5],
#   'sacks': [4.2, 2.0],
#   'total': 3.0},
#  'Tennessee Titans': {'passOFF': [186.8, 1.0],
#   'passDEF': [210.0, -1.5],
#   'sacks': [7.3, 0.0],
#   'times': [5.7, -1.0],
#   'rushOFF': [107.2, 0.0],
#   'rushDEF': [123.2, 1.0],
#   'total': -0.5},
#  'Dallas Cowboys': {'passOFF': [172.0, 1.5],
#   'sacks': [8.1, -0.5],
#   'rushOFF': [135.8, -1.5],
#   'rushDEF': [95.8, -0.5],
#   'passDEF': [241.6, -1.0],
#   'times': [10.0, 0.5],
#   'total': -1.5},
#  'Arizona Cardinals': {'passOFF': [146.2, 2.0],
#   'sacks': [7.3, 0.0],
#   'passDEF': [248.6, -0.5],
#   'times': [6.1, -1.0],
#   'rushDEF': [142.4, 2.0],
#   'rushOFF': [64.6, 2.0],
#   'total': 4.5},
#  'Buffalo Bills': {'passOFF': [121.8, 2.0],
#   'passDEF': [234.6, -1.0],
#   'rushDEF': [96.2, -0.5],
#   'sacks': [6.1, 1.0],
#   'rushOFF': [99.4, 0.5],
#   'times': [13.5, 2.0],
#   'total': 4.0}}

# %%
data_dict['Pittsburgh Steelers']
# Out:
# {'passOFF': [321.0, -1.5],
#  'sacks': [8.5, -0.5],
#  'times': [4.0, -2.0],
#  'rushDEF': [105.0, 0.0],
#  'rushOFF': [84.0, 1.5],
#  'passDEF': [296.2, 0.5],
#  'total': -2.0}

# %%
data_dict['Atlanta Falcons']
# Out:
# {'passOFF': [304.2, -1.0],
#  'passDEF': [277.2, 0.0],
#  'rushDEF': [121.4, 1.0],
#  'times': [7.8, 0.0],
#  'rushOFF': [89.2, 1.0],
#  'sacks': [3.9, 2.0],
#  'total': 3.0}
