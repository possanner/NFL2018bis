# %%
import numpy as np

# %%
def redpr(str):
    print('\x1b[31m' + str + '\x1b[0m')
    
def greenpr(str):
    print('\x1b[32m' + str + '\x1b[0m')
    
def colorpr2(str0, str1, col1, str2, col2):
    print(str0 + '\x1b[' + col1 + 'm' + str1 + '\x1b[0m', '   at  ', '\x1b[' + col2 + 'm' + str2 + '\x1b[0m')

# %%
week = 7
lastweek = week - 1
wk = str(week)
lwk = str(lastweek)

with open('schedule_2018.txt') as f:
    #passer = f.readlines()
    schedule = list(f)

with open('Week' + lwk + '/passingOFF_ydsper_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    passOFF = list(f)
    
with open('Week' + lwk + '/passingDEF_ydsper_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    passDEF = list(f)

with open('Week' + lwk + '/sacks_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    sacks = list(f)
    
with open('Week' + lwk + '/timessacked_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    times = list(f)
    
with open('Week' + lwk + '/rushingOFF_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    rushOFF = list(f)
    
with open('Week' + lwk + '/rushingDEF_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    rushDEF = list(f)

# %%
passOFF
# Out:
# ['1    Tampa Bay Buccaneers 10.0\n',
#  '2        Los Angeles Rams  9.9\n',
#  '3      Kansas City Chiefs  8.8\n',
#  '4    Los Angeles Chargers  8.8\n',
#  '5      New Orleans Saints  8.7\n',
#  '6         Atlanta Falcons  8.5\n',
#  '7          Houston Texans  8.2\n',
#  '8          Miami Dolphins  8.0\n',
#  '9     San Francisco 49ers  7.9\n',
#  '10       Seattle Seahawks  7.9\n',
#  '11    Pittsburgh Steelers  7.8\n',
#  '12      Green Bay Packers  7.8\n',
#  '13          Chicago Bears  7.8\n',
#  '14        Oakland Raiders  7.7\n',
#  '15   New England Patriots  7.5\n',
#  '16          New York Jets  7.5\n',
#  '17      Minnesota Vikings  7.4\n',
#  '18        New York Giants  7.4\n',
#  '19     Cincinnati Bengals  7.3\n',
#  '20         Denver Broncos  7.2\n',
#  '21   Jacksonville Jaguars  7.1\n',
#  '22          Detroit Lions  7.1\n',
#  '23    Washington Redskins  7.0\n',
#  '24    Philadelphia Eagles  6.9\n',
#  '25      Carolina Panthers  6.8\n',
#  '26       Baltimore Ravens  6.7\n',
#  '27         Dallas Cowboys  6.7\n',
#  '28       Tennessee Titans  6.7\n',
#  '29       Cleveland Browns  6.5\n',
#  '30     Indianapolis Colts  6.2\n',
#  '31      Arizona Cardinals  6.0\n',
#  '32          Buffalo Bills  5.4']

# %%
team_list = []
data_dict = {}

for i in range(len(passOFF)):
    
    # passing yards per game:
    team = passOFF[i][2:25].lstrip()
    team_list.append(team)
    
    val = float(passOFF[i].rstrip()[-4:])
    
    rnk = int(passOFF[i][0:2].rstrip())
    
    data_dict[team] = {}
    data_dict[team]['passOFF'] = [val, rnk]

    
for i in range(len(passOFF)):
    # passing yards allowed per game:
    team = passDEF[i][2:25].lstrip()
    
    val = float(passDEF[i].rstrip()[-4:])
    
    rnk = int(passDEF[i][0:2].rstrip())
    
    data_dict[team]['passDEF'] = [val, rnk]
    
    # sack percentage:
    team = sacks[i][2:25].lstrip()
    
    val = float(sacks[i].rstrip()[-4:])
    
    rnk = int(sacks[i][0:2].rstrip())
    
    data_dict[team]['sacks'] = [val, rnk]
    
    # times sacked percentage:
    team = times[i][2:25].lstrip()
    
    val = float(times[i].rstrip()[-4:])
    
    rnk = int(times[i][0:2].rstrip())
    
    data_dict[team]['times'] = [val, rnk]
    
    # rushing yards per game:
    team = rushOFF[i][2:25].lstrip()
    
    val = float(rushOFF[i].rstrip()[-5:])
    
    rnk = int(rushOFF[i][0:2].rstrip())
    
    data_dict[team]['rushOFF'] = [val, rnk]
    
    # rushing yards allowed per game:
    team = rushDEF[i][2:25].lstrip()
    
    val = float(rushDEF[i].rstrip()[-5:])
    
    rnk = int(rushDEF[i][0:2].rstrip())
    
    data_dict[team]['rushDEF'] = [val, rnk]
    
    
team_list = sorted(team_list)

# %%
passOFF_ar = []

for team in team_list:
    passOFF_ar.append(data_dict[team]['passOFF'][0])
    
ps = np.linspace(np.amin(passOFF_ar), np.amax(passOFF_ar), 10)
ps[0] = 0

for j in range(9):
    
    ind, = np.where(np.logical_and(passOFF_ar <= ps[j + 1], passOFF_ar > ps[j]))
    pts = 2 - j*0.5
        
    for i in ind:
        data_dict[team_list[i]]['passOFF'] =  [data_dict[team_list[i]]['passOFF'][0], pts]

# %%
passDEF_ar = []

for team in team_list:
    passDEF_ar.append(data_dict[team]['passDEF'][0])
    
ps = np.linspace(np.amin(passDEF_ar), np.amax(passDEF_ar), 10)
ps[0] = 0

for j in range(9):
    
    ind, = np.where(np.logical_and(passDEF_ar <= ps[j + 1], passDEF_ar > ps[j]))
    pts = -2 + j*0.5
        
    for i in ind:
        data_dict[team_list[i]]['passDEF'] =  [data_dict[team_list[i]]['passDEF'][0], pts]

# %%
sacks_ar = []

for team in team_list:
    sacks_ar.append(data_dict[team]['sacks'][0])
    
ps = np.linspace(np.amin(sacks_ar), np.amax(sacks_ar), 10)
ps[0] = 0

for j in range(9):
    
    ind, = np.where(np.logical_and(sacks_ar <= ps[j + 1], sacks_ar > ps[j]))
    pts = 2 - j*0.5
        
    for i in ind:
        data_dict[team_list[i]]['sacks'] =  [data_dict[team_list[i]]['sacks'][0], pts]

# %%
times_ar = []

for team in team_list:
    times_ar.append(data_dict[team]['times'][0])
    
ps = np.linspace(np.amin(times_ar), np.amax(times_ar), 10)
ps[0] = 0

for j in range(9):
    
    ind, = np.where(np.logical_and(times_ar <= ps[j + 1], times_ar > ps[j]))
    pts = -2 + j*0.5
        
    for i in ind:
        data_dict[team_list[i]]['times'] =  [data_dict[team_list[i]]['times'][0], pts]

# %%
rushOFF_ar = []

for team in team_list:
    rushOFF_ar.append(data_dict[team]['rushOFF'][0])
    
ps = np.linspace(np.amin(rushOFF_ar), np.amax(rushOFF_ar), 10)
ps[0] = 0

for j in range(9):
    
    ind, = np.where(np.logical_and(rushOFF_ar <= ps[j + 1], rushOFF_ar > ps[j]))
    pts = 2 - j*0.5
        
    for i in ind:
        data_dict[team_list[i]]['rushOFF'] =  [data_dict[team_list[i]]['rushOFF'][0], pts]

# %%
rushDEF_ar = []

for team in team_list:
    rushDEF_ar.append(data_dict[team]['rushDEF'][0])
    
ps = np.linspace(np.amin(rushDEF_ar), np.amax(rushDEF_ar), 10)
ps[0] = 0

for j in range(9):
    
    ind, = np.where(np.logical_and(rushDEF_ar <= ps[j + 1], rushDEF_ar > ps[j]))
    pts = - 2 + j*0.5
        
    for i in ind:
        data_dict[team_list[i]]['rushDEF'] =  [data_dict[team_list[i]]['rushDEF'][0], pts] 
    
print(ps)
data_dict
# Out:
# [   0.           81.38888889   91.37777778  101.36666667  111.35555556
#   121.34444444  131.33333333  141.32222222  151.31111111  161.3       ]
# {'Tampa Bay Buccaneers': {'passOFF': [10.0, -2.0],
#   'rushDEF': [84.2, -1.5],
#   'times': [11.0, -1.0],
#   'sacks': [9.0, 2.0],
#   'rushOFF': [80.2, 1.5],
#   'passDEF': [9.3, 2.0]},
#  'Los Angeles Rams': {'passOFF': [9.9, -2.0],
#   'rushOFF': [154.3, -2.0],
#   'times': [11.0, -1.0],
#   'rushDEF': [99.0, -1.0],
#   'passDEF': [7.5, 0.0],
#   'sacks': [12.0, 1.0]},
#  'Kansas City Chiefs': {'passOFF': [8.8, -1.0],
#   'times': [6.0, -2.0],
#   'sacks': [17.0, 0.0],
#   'rushOFF': [112.0, 0.0],
#   'passDEF': [7.9, 0.5],
#   'rushDEF': [127.8, 0.5]},
#  'Los Angeles Chargers': {'passOFF': [8.8, -1.0],
#   'times': [8.0, -2.0],
#   'rushOFF': [137.3, -1.5],
#   'rushDEF': [96.8, -1.0],
#   'sacks': [16.0, 0.0],
#   'passDEF': [7.8, 0.0]},
#  'New Orleans Saints': {'passOFF': [8.7, -1.0],
#   'rushDEF': [71.4, -2.0],
#   'times': [8.0, -2.0],
#   'rushOFF': [103.2, 0.5],
#   'sacks': [12.0, 1.0],
#   'passDEF': [9.1, 2.0]},
#  'Atlanta Falcons': {'passOFF': [8.5, -1.0],
#   'passDEF': [7.7, 0.0],
#   'times': [17.0, 0.0],
#   'rushDEF': [121.7, 0.5],
#   'sacks': [10.0, 1.5],
#   'rushOFF': [86.0, 1.0]},
#  'Houston Texans': {'passOFF': [8.2, -0.5],
#   'rushDEF': [95.8, -1.0],
#   'passDEF': [7.5, 0.0],
#   'rushOFF': [109.2, 0.0],
#   'sacks': [15.0, 0.5],
#   'times': [25.0, 2.0]},
#  'Miami Dolphins': {'passOFF': [8.0, -0.5],
#   'times': [11.0, -1.0],
#   'rushOFF': [106.8, 0.0],
#   'rushDEF': [118.2, 0.0],
#   'passDEF': [8.1, 0.5],
#   'sacks': [10.0, 1.5]},
#  'San Francisco 49ers': {'passOFF': [7.9, 0.0],
#   'rushOFF': [142.5, -1.5],
#   'rushDEF': [98.2, -1.0],
#   'passDEF': [7.4, -0.5],
#   'sacks': [12.0, 1.0],
#   'times': [20.0, 1.0]},
#  'Seattle Seahawks': {'passOFF': [7.9, 0.0],
#   'passDEF': [6.8, -1.0],
#   'rushOFF': [127.8, -1.0],
#   'sacks': [16.0, 0.0],
#   'rushDEF': [120.7, 0.0],
#   'times': [19.0, 0.5]},
#  'Pittsburgh Steelers': {'passOFF': [7.8, 0.0],
#   'sacks': [22.0, -1.5],
#   'times': [9.0, -1.5],
#   'rushDEF': [97.8, -1.0],
#   'passDEF': [7.4, -0.5],
#   'rushOFF': [88.7, 1.0]},
#  'Green Bay Packers': {'passOFF': [7.8, 0.0],
#   'sacks': [18.0, -0.5],
#   'rushOFF': [103.7, 0.5],
#   'passDEF': [7.5, 0.0],
#   'rushDEF': [116.5, 0.0],
#   'times': [21.0, 1.0]},
#  'Chicago Bears': {'passOFF': [7.8, 0.0],
#   'rushDEF': [83.4, -1.5],
#   'sacks': [18.0, -0.5],
#   'rushOFF': [130.0, -1.0],
#   'times': [12.0, -1.0],
#   'passDEF': [7.8, 0.0]},
#  'Oakland Raiders': {'passOFF': [7.7, 0.0],
#   'times': [17.0, 0.0],
#   'rushOFF': [92.5, 1.0],
#   'rushDEF': [131.8, 1.0],
#   'passDEF': [9.0, 2.0],
#   'sacks': [7.0, 2.0]},
#  'New England Patriots': {'passOFF': [7.5, 0.0],
#   'times': [8.0, -2.0],
#   'passDEF': [7.1, -1.0],
#   'rushOFF': [123.0, -0.5],
#   'rushDEF': [110.7, -0.5],
#   'sacks': [7.0, 2.0]},
#  'New York Jets': {'passOFF': [7.5, 0.0],
#   'rushOFF': [130.3, -1.0],
#   'passDEF': [7.2, -0.5],
#   'times': [13.0, -0.5],
#   'rushDEF': [108.7, -0.5],
#   'sacks': [14.0, 0.5]},
#  'Minnesota Vikings': {'passOFF': [7.4, 0.5],
#   'sacks': [18.0, -0.5],
#   'rushDEF': [93.0, -1.0],
#   'times': [18.0, 0.5],
#   'rushOFF': [87.3, 1.0],
#   'passDEF': [8.9, 1.5]},
#  'New York Giants': {'passOFF': [7.4, 0.5],
#   'passDEF': [7.2, -0.5],
#   'rushDEF': [121.7, 0.5],
#   'rushOFF': [87.5, 1.0],
#   'times': [20.0, 1.0],
#   'sacks': [7.0, 2.0]},
#  'Cincinnati Bengals': {'passOFF': [7.3, 0.5],
#   'passDEF': [7.2, -0.5],
#   'times': [12.0, -1.0],
#   'rushDEF': [117.2, 0.0],
#   'sacks': [13.0, 1.0],
#   'rushOFF': [89.8, 1.0]},
#  'Denver Broncos': {'passOFF': [7.2, 0.5],
#   'rushOFF': [124.2, -0.5],
#   'sacks': [16.0, 0.0],
#   'times': [15.0, 0.0],
#   'passDEF': [7.8, 0.0],
#   'rushDEF': [161.3, 2.0]},
#  'Jacksonville Jaguars': {'passOFF': [7.1, 0.5],
#   'passDEF': [6.4, -1.5],
#   'sacks': [14.0, 0.5],
#   'times': [14.0, -0.5],
#   'rushOFF': [103.3, 0.5],
#   'rushDEF': [118.7, 0.0]},
#  'Detroit Lions': {'passOFF': [7.1, 0.5],
#   'times': [9.0, -1.5],
#   'sacks': [17.0, 0.0],
#   'rushOFF': [97.2, 0.5],
#   'passDEF': [8.1, 0.5],
#   'rushDEF': [145.8, 1.5]},
#  'Washington Redskins': {'passOFF': [7.0, 0.5],
#   'passDEF': [6.9, -1.0],
#   'rushDEF': [90.2, -1.5],
#   'times': [12.0, -1.0],
#   'rushOFF': [116.8, -0.5],
#   'sacks': [10.0, 1.5]},
#  'Philadelphia Eagles': {'passOFF': [6.9, 1.0],
#   'rushDEF': [79.8, -2.0],
#   'passDEF': [7.3, -0.5],
#   'rushOFF': [110.3, 0.0],
#   'sacks': [16.0, 0.0],
#   'times': [18.0, 0.5]},
#  'Carolina Panthers': {'passOFF': [6.8, 1.0],
#   'times': [8.0, -2.0],
#   'rushOFF': [139.4, -1.5],
#   'rushDEF': [102.4, -0.5],
#   'passDEF': [7.6, 0.0],
#   'sacks': [12.0, 1.0]},
#  'Baltimore Ravens': {'passOFF': [6.7, 1.0],
#   'passDEF': [6.0, -2.0],
#   'sacks': [26.0, -2.0],
#   'rushDEF': [82.8, -1.5],
#   'times': [12.0, -1.0],
#   'rushOFF': [99.2, 0.5]},
#  'Dallas Cowboys': {'passOFF': [6.7, 1.0],
#   'rushOFF': [147.5, -2.0],
#   'sacks': [18.0, -0.5],
#   'rushDEF': [90.7, -1.5],
#   'passDEF': [7.5, 0.0],
#   'times': [19.0, 0.5]},
#  'Tennessee Titans': {'passOFF': [6.7, 1.0],
#   'passDEF': [6.8, -1.0],
#   'sacks': [13.0, 1.0],
#   'rushOFF': [98.5, 0.5],
#   'times': [20.0, 1.0],
#   'rushDEF': [123.2, 0.5]},
#  'Cleveland Browns': {'passOFF': [6.5, 1.0],
#   'rushOFF': [137.7, -1.5],
#   'passDEF': [7.0, -1.0],
#   'sacks': [15.0, 0.5],
#   'rushDEF': [138.2, 1.0],
#   'times': [26.0, 2.0]},
#  'Indianapolis Colts': {'passOFF': [6.2, 1.5],
#   'sacks': [19.0, -0.5],
#   'times': [10.0, -1.5],
#   'rushDEF': [106.8, -0.5],
#   'passDEF': [7.9, 0.5],
#   'rushOFF': [83.2, 1.5]},
#  'Arizona Cardinals': {'passOFF': [6.0, 1.5],
#   'sacks': [18.0, -0.5],
#   'times': [13.0, -0.5],
#   'passDEF': [7.5, 0.0],
#   'rushDEF': [151.2, 1.5],
#   'rushOFF': [64.0, 2.0]},
#  'Buffalo Bills': {'passOFF': [5.4, 2.0],
#   'passDEF': [6.7, -1.5],
#   'sacks': [19.0, -0.5],
#   'rushDEF': [92.5, -1.0],
#   'rushOFF': [99.5, 0.5],
#   'times': [24.0, 2.0]}}

# %%
total_list = []

for team in team_list:
    data_dict[team]['total'] = (data_dict[team]['passOFF'][1]
    + data_dict[team]['passDEF'][1]
    + data_dict[team]['sacks'][1]
    + data_dict[team]['times'][1]
    + data_dict[team]['rushOFF'][1]
    + data_dict[team]['rushDEF'][1])
    
    total_list.append([data_dict[team]['total'], team])

# %%
power_rankings = sorted(total_list)
print('Power rankings:')
print()
for i in range(32):
    print('{:2d}'.format(i + 1), power_rankings[i][1].rjust(22), '{0:+.1f}'.format(power_rankings[i][0] ))
# Out:
# Power rankings:
#
#  1   Los Angeles Chargers -5.5
#  2       Baltimore Ravens -5.0
#  3       Los Angeles Rams -5.0
#  4          Chicago Bears -4.0
#  5    Pittsburgh Steelers -3.5
#  6         Dallas Cowboys -2.5
#  7      Carolina Panthers -2.0
#  8     Kansas City Chiefs -2.0
#  9   New England Patriots -2.0
# 10          New York Jets -2.0
# 11    Washington Redskins -2.0
# 12     New Orleans Saints -1.5
# 13       Seattle Seahawks -1.5
# 14    Philadelphia Eagles -1.0
# 15    San Francisco 49ers -1.0
# 16   Jacksonville Jaguars -0.5
# 17         Miami Dolphins +0.5
# 18     Cincinnati Bengals +1.0
# 19      Green Bay Packers +1.0
# 20         Houston Texans +1.0
# 21     Indianapolis Colts +1.0
# 22   Tampa Bay Buccaneers +1.0
# 23          Buffalo Bills +1.5
# 24          Detroit Lions +1.5
# 25        Atlanta Falcons +2.0
# 26       Cleveland Browns +2.0
# 27         Denver Broncos +2.0
# 28      Minnesota Vikings +2.0
# 29       Tennessee Titans +3.0
# 30      Arizona Cardinals +4.0
# 31        New York Giants +4.5
# 32        Oakland Raiders +6.0

# %%
for i in range(len(schedule)):
    if ( schedule[i][0]==wk and schedule[i][1]==' ' ) or schedule[i][0:2]==wk:
        
        team_away = schedule[i][3:29].lstrip().rstrip()
        team_home = schedule[i][28:].lstrip().rstrip()
        
        spread =  2.5 + data_dict[team_away]['total'] - data_dict[team_home]['total']
        
        print(team_away.rjust(22) + ' {0:+5.1f}   at   '.format(spread) + team_home )
# Out:
#         Denver Broncos  +0.5   at   Arizona Cardinals
#       Tennessee Titans +11.0   at   Los Angeles Chargers
#          Buffalo Bills  +3.0   at   Indianapolis Colts
#   New England Patriots  +4.5   at   Chicago Bears
#      Carolina Panthers  +1.5   at   Philadelphia Eagles
#      Minnesota Vikings  +6.5   at   New York Jets
#       Cleveland Browns  +3.5   at   Tampa Bay Buccaneers
#          Detroit Lions  +3.5   at   Miami Dolphins
#         Houston Texans  +4.0   at   Jacksonville Jaguars
#     Cincinnati Bengals  +5.5   at   Kansas City Chiefs
#     New Orleans Saints  +6.0   at   Baltimore Ravens
#         Dallas Cowboys  +2.0   at   Washington Redskins
#       Los Angeles Rams  -1.5   at   San Francisco 49ers
#        New York Giants  +5.0   at   Atlanta Falcons

# %%
div_list = []
team = 'Miami Dolphins'
div_list.append([data_dict[team]['total'], team])
team = 'New England Patriots'
div_list.append([data_dict[team]['total'], team])
team = 'New York Jets'
div_list.append([data_dict[team]['total'], team])
team = 'Buffalo Bills'
div_list.append([data_dict[team]['total'], team])
AFC_east = sorted(div_list)
for i in range(4):
    print(AFC_east[i][1].rjust(22), AFC_east[i][0])
# Out:
#   New England Patriots -2.0
#          New York Jets -2.0
#         Miami Dolphins 0.5
#          Buffalo Bills 1.5

# %%
div_list = []
team = 'Cincinnati Bengals'
div_list.append([data_dict[team]['total'], team])
team = 'Baltimore Ravens'
div_list.append([data_dict[team]['total'], team])
team = 'Pittsburgh Steelers'
div_list.append([data_dict[team]['total'], team])
team = 'Cleveland Browns'
div_list.append([data_dict[team]['total'], team])
AFC_north = sorted(div_list)
for i in range(4):
    print(AFC_north[i][1].rjust(22), AFC_north[i][0])
# Out:
#       Baltimore Ravens -5.0
#    Pittsburgh Steelers -3.5
#     Cincinnati Bengals 1.0
#       Cleveland Browns 2.0

# %%
div_list = []
team = 'Tennessee Titans'
div_list.append([data_dict[team]['total'], team])
team = 'Jacksonville Jaguars'
div_list.append([data_dict[team]['total'], team])
team = 'Indianapolis Colts'
div_list.append([data_dict[team]['total'], team])
team = 'Houston Texans'
div_list.append([data_dict[team]['total'], team])
AFC_south = sorted(div_list)
for i in range(4):
    print(AFC_south[i][1].rjust(22), AFC_south[i][0])
# Out:
#   Jacksonville Jaguars -0.5
#         Houston Texans 1.0
#     Indianapolis Colts 1.0
#       Tennessee Titans 3.0

# %%
div_list = []
team = 'Kansas City Chiefs'
div_list.append([data_dict[team]['total'], team])
team = 'Denver Broncos'
div_list.append([data_dict[team]['total'], team])
team = 'Los Angeles Chargers'
div_list.append([data_dict[team]['total'], team])
team = 'Oakland Raiders'
div_list.append([data_dict[team]['total'], team])
AFC_west = sorted(div_list)
for i in range(4):
    print(AFC_west[i][1].rjust(22), AFC_west[i][0])
# Out:
#   Los Angeles Chargers -5.5
#     Kansas City Chiefs -2.0
#         Denver Broncos 2.0
#        Oakland Raiders 6.0

# %%
div_list = []
team = 'Washington Redskins'
div_list.append([data_dict[team]['total'], team])
team = 'Philadelphia Eagles'
div_list.append([data_dict[team]['total'], team])
team = 'New York Giants'
div_list.append([data_dict[team]['total'], team])
team = 'Dallas Cowboys'
div_list.append([data_dict[team]['total'], team])
NFC_east = sorted(div_list)
for i in range(4):
    print(NFC_east[i][1].rjust(22), NFC_east[i][0])
# Out:
#         Dallas Cowboys -2.5
#    Washington Redskins -2.0
#    Philadelphia Eagles -1.0
#        New York Giants 4.5

# %%
div_list = []
team = 'Chicago Bears'
div_list.append([data_dict[team]['total'], team])
team = 'Green Bay Packers'
div_list.append([data_dict[team]['total'], team])
team = 'Detroit Lions'
div_list.append([data_dict[team]['total'], team])
team = 'Minnesota Vikings'
div_list.append([data_dict[team]['total'], team])
NFC_north = sorted(div_list)
for i in range(4):
    print(NFC_north[i][1].rjust(22), NFC_north[i][0])
# Out:
#          Chicago Bears -4.0
#      Green Bay Packers 1.0
#          Detroit Lions 1.5
#      Minnesota Vikings 2.0

# %%
div_list = []
team = 'New Orleans Saints'
div_list.append([data_dict[team]['total'], team])
team = 'Tampa Bay Buccaneers'
div_list.append([data_dict[team]['total'], team])
team = 'Atlanta Falcons'
div_list.append([data_dict[team]['total'], team])
team = 'Carolina Panthers'
div_list.append([data_dict[team]['total'], team])
NFC_south = sorted(div_list)
for i in range(4):
    print(NFC_south[i][1].rjust(22), NFC_south[i][0])
# Out:
#      Carolina Panthers -2.0
#     New Orleans Saints -1.5
#   Tampa Bay Buccaneers 1.0
#        Atlanta Falcons 2.0

# %%
div_list = []
team = 'Los Angeles Rams'
div_list.append([data_dict[team]['total'], team])
team = 'Seattle Seahawks'
div_list.append([data_dict[team]['total'], team])
team = 'Arizona Cardinals'
div_list.append([data_dict[team]['total'], team])
team = 'San Francisco 49ers'
div_list.append([data_dict[team]['total'], team])
NFC_west = sorted(div_list)
for i in range(4):
    print(NFC_west[i][1].rjust(22), NFC_west[i][0])
# Out:
#       Los Angeles Rams -5.0
#       Seattle Seahawks -1.5
#    San Francisco 49ers -1.0
#      Arizona Cardinals 4.0

# %%
data_dict
# Out:
# {'Tampa Bay Buccaneers': {'passOFF': [10.0, -2.0],
#   'rushDEF': [84.2, -1.5],
#   'times': [11.0, -1.0],
#   'sacks': [9.0, 2.0],
#   'rushOFF': [80.2, 1.5],
#   'passDEF': [9.3, 2.0],
#   'total': 1.0},
#  'Los Angeles Rams': {'passOFF': [9.9, -2.0],
#   'rushOFF': [154.3, -2.0],
#   'times': [11.0, -1.0],
#   'rushDEF': [99.0, -1.0],
#   'passDEF': [7.5, 0.0],
#   'sacks': [12.0, 1.0],
#   'total': -5.0},
#  'Kansas City Chiefs': {'passOFF': [8.8, -1.0],
#   'times': [6.0, -2.0],
#   'sacks': [17.0, 0.0],
#   'rushOFF': [112.0, 0.0],
#   'passDEF': [7.9, 0.5],
#   'rushDEF': [127.8, 0.5],
#   'total': -2.0},
#  'Los Angeles Chargers': {'passOFF': [8.8, -1.0],
#   'times': [8.0, -2.0],
#   'rushOFF': [137.3, -1.5],
#   'rushDEF': [96.8, -1.0],
#   'sacks': [16.0, 0.0],
#   'passDEF': [7.8, 0.0],
#   'total': -5.5},
#  'New Orleans Saints': {'passOFF': [8.7, -1.0],
#   'rushDEF': [71.4, -2.0],
#   'times': [8.0, -2.0],
#   'rushOFF': [103.2, 0.5],
#   'sacks': [12.0, 1.0],
#   'passDEF': [9.1, 2.0],
#   'total': -1.5},
#  'Atlanta Falcons': {'passOFF': [8.5, -1.0],
#   'passDEF': [7.7, 0.0],
#   'times': [17.0, 0.0],
#   'rushDEF': [121.7, 0.5],
#   'sacks': [10.0, 1.5],
#   'rushOFF': [86.0, 1.0],
#   'total': 2.0},
#  'Houston Texans': {'passOFF': [8.2, -0.5],
#   'rushDEF': [95.8, -1.0],
#   'passDEF': [7.5, 0.0],
#   'rushOFF': [109.2, 0.0],
#   'sacks': [15.0, 0.5],
#   'times': [25.0, 2.0],
#   'total': 1.0},
#  'Miami Dolphins': {'passOFF': [8.0, -0.5],
#   'times': [11.0, -1.0],
#   'rushOFF': [106.8, 0.0],
#   'rushDEF': [118.2, 0.0],
#   'passDEF': [8.1, 0.5],
#   'sacks': [10.0, 1.5],
#   'total': 0.5},
#  'San Francisco 49ers': {'passOFF': [7.9, 0.0],
#   'rushOFF': [142.5, -1.5],
#   'rushDEF': [98.2, -1.0],
#   'passDEF': [7.4, -0.5],
#   'sacks': [12.0, 1.0],
#   'times': [20.0, 1.0],
#   'total': -1.0},
#  'Seattle Seahawks': {'passOFF': [7.9, 0.0],
#   'passDEF': [6.8, -1.0],
#   'rushOFF': [127.8, -1.0],
#   'sacks': [16.0, 0.0],
#   'rushDEF': [120.7, 0.0],
#   'times': [19.0, 0.5],
#   'total': -1.5},
#  'Pittsburgh Steelers': {'passOFF': [7.8, 0.0],
#   'sacks': [22.0, -1.5],
#   'times': [9.0, -1.5],
#   'rushDEF': [97.8, -1.0],
#   'passDEF': [7.4, -0.5],
#   'rushOFF': [88.7, 1.0],
#   'total': -3.5},
#  'Green Bay Packers': {'passOFF': [7.8, 0.0],
#   'sacks': [18.0, -0.5],
#   'rushOFF': [103.7, 0.5],
#   'passDEF': [7.5, 0.0],
#   'rushDEF': [116.5, 0.0],
#   'times': [21.0, 1.0],
#   'total': 1.0},
#  'Chicago Bears': {'passOFF': [7.8, 0.0],
#   'rushDEF': [83.4, -1.5],
#   'sacks': [18.0, -0.5],
#   'rushOFF': [130.0, -1.0],
#   'times': [12.0, -1.0],
#   'passDEF': [7.8, 0.0],
#   'total': -4.0},
#  'Oakland Raiders': {'passOFF': [7.7, 0.0],
#   'times': [17.0, 0.0],
#   'rushOFF': [92.5, 1.0],
#   'rushDEF': [131.8, 1.0],
#   'passDEF': [9.0, 2.0],
#   'sacks': [7.0, 2.0],
#   'total': 6.0},
#  'New England Patriots': {'passOFF': [7.5, 0.0],
#   'times': [8.0, -2.0],
#   'passDEF': [7.1, -1.0],
#   'rushOFF': [123.0, -0.5],
#   'rushDEF': [110.7, -0.5],
#   'sacks': [7.0, 2.0],
#   'total': -2.0},
#  'New York Jets': {'passOFF': [7.5, 0.0],
#   'rushOFF': [130.3, -1.0],
#   'passDEF': [7.2, -0.5],
#   'times': [13.0, -0.5],
#   'rushDEF': [108.7, -0.5],
#   'sacks': [14.0, 0.5],
#   'total': -2.0},
#  'Minnesota Vikings': {'passOFF': [7.4, 0.5],
#   'sacks': [18.0, -0.5],
#   'rushDEF': [93.0, -1.0],
#   'times': [18.0, 0.5],
#   'rushOFF': [87.3, 1.0],
#   'passDEF': [8.9, 1.5],
#   'total': 2.0},
#  'New York Giants': {'passOFF': [7.4, 0.5],
#   'passDEF': [7.2, -0.5],
#   'rushDEF': [121.7, 0.5],
#   'rushOFF': [87.5, 1.0],
#   'times': [20.0, 1.0],
#   'sacks': [7.0, 2.0],
#   'total': 4.5},
#  'Cincinnati Bengals': {'passOFF': [7.3, 0.5],
#   'passDEF': [7.2, -0.5],
#   'times': [12.0, -1.0],
#   'rushDEF': [117.2, 0.0],
#   'sacks': [13.0, 1.0],
#   'rushOFF': [89.8, 1.0],
#   'total': 1.0},
#  'Denver Broncos': {'passOFF': [7.2, 0.5],
#   'rushOFF': [124.2, -0.5],
#   'sacks': [16.0, 0.0],
#   'times': [15.0, 0.0],
#   'passDEF': [7.8, 0.0],
#   'rushDEF': [161.3, 2.0],
#   'total': 2.0},
#  'Jacksonville Jaguars': {'passOFF': [7.1, 0.5],
#   'passDEF': [6.4, -1.5],
#   'sacks': [14.0, 0.5],
#   'times': [14.0, -0.5],
#   'rushOFF': [103.3, 0.5],
#   'rushDEF': [118.7, 0.0],
#   'total': -0.5},
#  'Detroit Lions': {'passOFF': [7.1, 0.5],
#   'times': [9.0, -1.5],
#   'sacks': [17.0, 0.0],
#   'rushOFF': [97.2, 0.5],
#   'passDEF': [8.1, 0.5],
#   'rushDEF': [145.8, 1.5],
#   'total': 1.5},
#  'Washington Redskins': {'passOFF': [7.0, 0.5],
#   'passDEF': [6.9, -1.0],
#   'rushDEF': [90.2, -1.5],
#   'times': [12.0, -1.0],
#   'rushOFF': [116.8, -0.5],
#   'sacks': [10.0, 1.5],
#   'total': -2.0},
#  'Philadelphia Eagles': {'passOFF': [6.9, 1.0],
#   'rushDEF': [79.8, -2.0],
#   'passDEF': [7.3, -0.5],
#   'rushOFF': [110.3, 0.0],
#   'sacks': [16.0, 0.0],
#   'times': [18.0, 0.5],
#   'total': -1.0},
#  'Carolina Panthers': {'passOFF': [6.8, 1.0],
#   'times': [8.0, -2.0],
#   'rushOFF': [139.4, -1.5],
#   'rushDEF': [102.4, -0.5],
#   'passDEF': [7.6, 0.0],
#   'sacks': [12.0, 1.0],
#   'total': -2.0},
#  'Baltimore Ravens': {'passOFF': [6.7, 1.0],
#   'passDEF': [6.0, -2.0],
#   'sacks': [26.0, -2.0],
#   'rushDEF': [82.8, -1.5],
#   'times': [12.0, -1.0],
#   'rushOFF': [99.2, 0.5],
#   'total': -5.0},
#  'Dallas Cowboys': {'passOFF': [6.7, 1.0],
#   'rushOFF': [147.5, -2.0],
#   'sacks': [18.0, -0.5],
#   'rushDEF': [90.7, -1.5],
#   'passDEF': [7.5, 0.0],
#   'times': [19.0, 0.5],
#   'total': -2.5},
#  'Tennessee Titans': {'passOFF': [6.7, 1.0],
#   'passDEF': [6.8, -1.0],
#   'sacks': [13.0, 1.0],
#   'rushOFF': [98.5, 0.5],
#   'times': [20.0, 1.0],
#   'rushDEF': [123.2, 0.5],
#   'total': 3.0},
#  'Cleveland Browns': {'passOFF': [6.5, 1.0],
#   'rushOFF': [137.7, -1.5],
#   'passDEF': [7.0, -1.0],
#   'sacks': [15.0, 0.5],
#   'rushDEF': [138.2, 1.0],
#   'times': [26.0, 2.0],
#   'total': 2.0},
#  'Indianapolis Colts': {'passOFF': [6.2, 1.5],
#   'sacks': [19.0, -0.5],
#   'times': [10.0, -1.5],
#   'rushDEF': [106.8, -0.5],
#   'passDEF': [7.9, 0.5],
#   'rushOFF': [83.2, 1.5],
#   'total': 1.0},
#  'Arizona Cardinals': {'passOFF': [6.0, 1.5],
#   'sacks': [18.0, -0.5],
#   'times': [13.0, -0.5],
#   'passDEF': [7.5, 0.0],
#   'rushDEF': [151.2, 1.5],
#   'rushOFF': [64.0, 2.0],
#   'total': 4.0},
#  'Buffalo Bills': {'passOFF': [5.4, 2.0],
#   'passDEF': [6.7, -1.5],
#   'sacks': [19.0, -0.5],
#   'rushDEF': [92.5, -1.0],
#   'rushOFF': [99.5, 0.5],
#   'times': [24.0, 2.0],
#   'total': 1.5}}

# %%
data_dict['Pittsburgh Steelers']
# Out:
# {'passOFF': [7.8, 0.0],
#  'sacks': [22.0, -1.5],
#  'times': [9.0, -1.5],
#  'rushDEF': [97.8, -1.0],
#  'passDEF': [7.4, -0.5],
#  'rushOFF': [88.7, 1.0],
#  'total': -3.5}

# %%
data_dict['Atlanta Falcons']
# Out:
# {'passOFF': [8.5, -1.0],
#  'passDEF': [7.7, 0.0],
#  'times': [17.0, 0.0],
#  'rushDEF': [121.7, 0.5],
#  'sacks': [10.0, 1.5],
#  'rushOFF': [86.0, 1.0],
#  'total': 2.0}
