# %%
import numpy as np

# %%
def redpr(str):
    print('\x1b[31m' + str + '\x1b[0m')
    
def greenpr(str):
    print('\x1b[32m' + str + '\x1b[0m')
    
def colorpr2(strA, str1, col1, strB, str2, col2):
    print(strA + '\x1b[' + col1 + 'm' + str1.rjust(6) + '\x1b[0m    ', strB.ljust(16) + '\x1b[' + col2 + 'm' + str2.rjust(6) + '\x1b[0m')

# %%
week = 12
lastweek = week - 1
wk = str(week)
lwk = str(lastweek)

with open('schedule_2018.txt') as f:
    #passer = f.readlines()
    schedule = list(f)

with open('Week' + lwk + '/SRS_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    SRS = list(f)
    
with open('Week' + lwk + '/interceptOFF_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    interceptOFF = list(f)
    
with open('Week' + lwk + '/interceptDEF_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    interceptDEF = list(f)
    
with open('Week' + lwk + '/timessacked_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    timessacked = list(f)

with open('Week' + lwk + '/sacks_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    sacks = list(f)
    
with open('Week' + lwk + '/rushingOFF_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    rushOFF = list(f)
    
with open('Week' + lwk + '/rushingDEF_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    rushDEF = list(f)
    
with open('Week' + lwk + '/3DconvOFF_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    DconvOFF = list(f)
    
with open('Week' + lwk + '/3DconvDEF_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    DconvDEF = list(f)
    
with open('Week' + lwk + '/redzoneOFF_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    redzoneOFF = list(f)
    
with open('Week' + lwk + '/redzoneDEF_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    redzoneDEF = list(f)

# %%
team_list = []
data_dict = {}

for i in range(len(SRS)):
    
    # SRS:
    team = SRS[i][:22].lstrip().rstrip()
    team_list.append(team)
    
    val = float(SRS[i].rstrip()[-7:])
    
    data_dict[team] = {}
    data_dict[team]['SRS'] = val
    
data_dict

    
for i in range(len(SRS)):    
    # interceptions OFFENSE:
    team = interceptOFF[i][2:25].lstrip()
    
    val = float(interceptOFF[i].rstrip()[-3:])
    
    rnk = int(interceptOFF[i][0:2].rstrip())
    
    data_dict[team]['interceptOFF'] = [val, rnk]
    
    # interceptions DEFENSE:
    team = interceptDEF[i][2:25].lstrip()
    
    val = float(interceptDEF[i].rstrip()[-3:])
    
    rnk = int(interceptDEF[i][0:2].rstrip())
    
    data_dict[team]['interceptDEF'] = [val, rnk]
    
    # timessacked:
    team = timessacked[i][2:25].lstrip()
    
    val = float(timessacked[i].rstrip()[-3:])
    
    rnk = int(timessacked[i][0:2].rstrip())
    
    data_dict[team]['timessacked'] = [val, rnk]
    
    # sacks:
    team = sacks[i][2:25].lstrip()
    
    val = float(sacks[i].rstrip()[-3:])
    
    rnk = int(sacks[i][0:2].rstrip())
    
    data_dict[team]['sacks'] = [val, rnk]
    
    # rushing offense:
    team = rushOFF[i][2:25].lstrip()
    
    val = float(rushOFF[i].rstrip()[-5:])
    
    rnk = int(rushOFF[i][0:2].rstrip())
    
    data_dict[team]['rushOFF'] = [val, rnk]
    
    # rushing defense:
    team = rushDEF[i][2:25].lstrip()
    
    val = float(rushDEF[i].rstrip()[-5:])
    
    rnk = int(rushDEF[i][0:2].rstrip())
    
    data_dict[team]['rushDEF'] = [val, rnk]
    
    # 3rd down conversions offense:
    team = DconvOFF[i][2:25].lstrip()
    
    val = float(DconvOFF[i].rstrip()[-5:-1])
    
    rnk = int(DconvOFF[i][0:2].rstrip())
    
    data_dict[team]['3DconvOFF'] = [val, rnk]
    
    # 3rd down conversions defense:
    team = DconvDEF[i][2:25].lstrip()
    
    val = float(DconvDEF[i].rstrip()[-5:-1])
    
    rnk = int(DconvDEF[i][0:2].rstrip())
    
    data_dict[team]['3DconvDEF'] = [val, rnk]
    
    # redzone offense:
    team = redzoneOFF[i][2:25].lstrip()
    
    val = float(redzoneOFF[i].rstrip()[-5:-1])
    
    rnk = int(redzoneOFF[i][0:2].rstrip())
    
    data_dict[team]['redzoneOFF'] = [val, rnk]
    
    # redzone defense:
    team = redzoneDEF[i][2:25].lstrip()
    
    val = float(redzoneDEF[i].rstrip()[-5:-1])
    
    rnk = int(redzoneDEF[i][0:2].rstrip())
    
    data_dict[team]['redzoneDEF'] = [val, rnk]
    
    
team_list = sorted(team_list)

# %%
SRS_ar = []
OFF_ar = []
DEF_ar = []
pow_ar = []

for team in team_list:
    SRS_ar.append([data_dict[team]['SRS'], team]) 
    rnk_3 = data_dict[team]['interceptOFF'][1]
    rnk_5 = data_dict[team]['timessacked'][1]
    rnk_9 = data_dict[team]['rushOFF'][1]
    rnk_13 = data_dict[team]['3DconvOFF'][1]
    rnk_17 = data_dict[team]['redzoneOFF'][1]
    
    OFF_val = np.mean([rnk_3, rnk_5, rnk_9, rnk_13, rnk_17])
    OFF_ar.append([OFF_val, team, rnk_3, rnk_5, rnk_9, rnk_13, rnk_17])
    
    rnk_1 = data_dict[team]['interceptDEF'][1]
    rnk_7 = data_dict[team]['sacks'][1]
    rnk_11 = data_dict[team]['rushDEF'][1]
    rnk_15 = data_dict[team]['3DconvDEF'][1]
    rnk_19 = data_dict[team]['redzoneDEF'][1]
    
    DEF_val = np.mean([rnk_1, rnk_7, rnk_11, rnk_15, rnk_19])
    DEF_ar.append([DEF_val, team, rnk_1, rnk_7, rnk_11, rnk_15, rnk_19])
    
    pow_ar.append([data_dict[team]['SRS'], team])

    
SRS_rankings = sorted(SRS_ar, reverse=True)
power_OFF = sorted(OFF_ar, reverse=False)
power_DEF = sorted(DEF_ar, reverse=False)
power_rankings = sorted(pow_ar, reverse=True)


print('Power rankings:')
print()
for i in range(32):
    print('{:2d}'.format(i + 1), power_rankings[i][1].rjust(22), '{0:+5.1f}'.format(power_rankings[i][0] ))
    
print()
print('SRS:')
print()
for i in range(32):
    print('{:2d}'.format(i + 1), SRS_rankings[i][1].rjust(22), '{0:+5.1f}'.format(SRS_rankings[i][0] ))
    
print()
print('Offense:')
print()
for i in range(32):
    print('{:2d}'.format(i + 1), power_OFF[i][1].rjust(22), '{0:4.1f}'.format(power_OFF[i][0]), '   {}'.format(power_OFF[i][2:]))
    team = power_OFF[i][1].lstrip().rstrip()
    data_dict[team]['OFFENSE'] = [i+1, power_OFF[i][0]]
    
print()
print('Defense:')
print()
for i in range(32):
    print('{:2d}'.format(i + 1), power_DEF[i][1].rjust(22), '{0:4.1f}'.format(power_DEF[i][0]), '   {}'.format(power_DEF[i][2:]))
    team = power_DEF[i][1].lstrip().rstrip()
    data_dict[team]['DEFENSE'] = [i+1, power_DEF[i][0]]
# Out:
# Power rankings:
#
#  1     New Orleans Saints +14.1
#  2     Kansas City Chiefs +10.8
#  3       Los Angeles Rams +10.6
#  4    Pittsburgh Steelers  +8.5
#  5       Baltimore Ravens  +7.3
#  6          Chicago Bears  +6.0
#  7       Seattle Seahawks  +4.1
#  8   New England Patriots  +3.8
#  9   Los Angeles Chargers  +3.8
# 10         Houston Texans  +1.8
# 11     Indianapolis Colts  +1.6
# 12         Denver Broncos  +1.3
# 13         Dallas Cowboys  +0.6
# 14      Minnesota Vikings  +0.5
# 15      Carolina Panthers  +0.5
# 16      Green Bay Packers  +0.1
# 17    Washington Redskins  -0.6
# 18        Atlanta Falcons  -0.9
# 19       Tennessee Titans  -1.1
# 20     Cincinnati Bengals  -1.9
# 21       Cleveland Browns  -2.1
# 22    Philadelphia Eagles  -2.3
# 23   Jacksonville Jaguars  -3.5
# 24   Tampa Bay Buccaneers  -4.1
# 25          Detroit Lions  -4.6
# 26        New York Giants  -4.8
# 27    San Francisco 49ers  -5.1
# 28          New York Jets  -7.2
# 29         Miami Dolphins  -7.9
# 30          Buffalo Bills  -9.3
# 31      Arizona Cardinals  -9.7
# 32        Oakland Raiders -12.3
#
# SRS:
#
#  1     New Orleans Saints +14.1
#  2     Kansas City Chiefs +10.8
#  3       Los Angeles Rams +10.6
#  4    Pittsburgh Steelers  +8.5
#  5       Baltimore Ravens  +7.3
#  6          Chicago Bears  +6.0
#  7       Seattle Seahawks  +4.1
#  8   New England Patriots  +3.8
#  9   Los Angeles Chargers  +3.8
# 10         Houston Texans  +1.8
# 11     Indianapolis Colts  +1.6
# 12         Denver Broncos  +1.3
# 13         Dallas Cowboys  +0.6
# 14      Minnesota Vikings  +0.5
# 15      Carolina Panthers  +0.5
# 16      Green Bay Packers  +0.1
# 17    Washington Redskins  -0.6
# 18        Atlanta Falcons  -0.9
# 19       Tennessee Titans  -1.1
# 20     Cincinnati Bengals  -1.9
# 21       Cleveland Browns  -2.1
# 22    Philadelphia Eagles  -2.3
# 23   Jacksonville Jaguars  -3.5
# 24   Tampa Bay Buccaneers  -4.1
# 25          Detroit Lions  -4.6
# 26        New York Giants  -4.8
# 27    San Francisco 49ers  -5.1
# 28          New York Jets  -7.2
# 29         Miami Dolphins  -7.9
# 30          Buffalo Bills  -9.3
# 31      Arizona Cardinals  -9.7
# 32        Oakland Raiders -12.3
#
# Offense:
#
#  1     New Orleans Saints  3.2    [1, 1, 6, 5, 3]
#  2      Carolina Panthers  7.6    [7, 8, 7, 12, 4]
#  3     Indianapolis Colts  8.4    [17, 2, 14, 1, 8]
#  4       Los Angeles Rams  9.4    [7, 14, 2, 8, 16]
#  5       Baltimore Ravens 10.4    [11, 7, 16, 7, 11]
#  6          Chicago Bears 11.0    [17, 6, 10, 10, 12]
#  7     Kansas City Chiefs 11.0    [23, 9, 13, 4, 6]
#  8   New England Patriots 11.6    [11, 4, 19, 14, 10]
#  9       Seattle Seahawks 11.6    [4, 24, 1, 22, 7]
# 10        Atlanta Falcons 12.0    [3, 17, 29, 2, 9]
# 11    Pittsburgh Steelers 12.0    [23, 3, 26, 6, 2]
# 12   Los Angeles Chargers 12.6    [7, 5, 9, 23, 19]
# 13    Washington Redskins 13.6    [4, 12, 12, 20, 20]
# 14     Cincinnati Bengals 15.6    [23, 10, 28, 16, 1]
# 15      Green Bay Packers 15.6    [2, 25, 18, 19, 14]
# 16       Tennessee Titans 17.0    [15, 26, 15, 11, 18]
# 17         Dallas Cowboys 17.2    [4, 30, 4, 24, 24]
# 18         Denver Broncos 18.6    [23, 13, 8, 27, 22]
# 19    Philadelphia Eagles 18.6    [11, 23, 25, 13, 21]
# 20   Jacksonville Jaguars 19.0    [17, 20, 22, 9, 27]
# 21    San Francisco 49ers 19.2    [28, 22, 3, 15, 28]
# 22      Minnesota Vikings 19.4    [11, 15, 31, 17, 23]
# 23   Tampa Bay Buccaneers 19.4    [32, 18, 27, 3, 17]
# 24       Cleveland Browns 20.2    [23, 31, 5, 29, 13]
# 25         Houston Texans 20.4    [17, 27, 11, 18, 29]
# 26          Detroit Lions 21.6    [17, 21, 24, 21, 25]
# 27         Miami Dolphins 22.6    [17, 16, 21, 28, 31]
# 28      Arizona Cardinals 23.2    [29, 19, 32, 31, 5]
# 29          Buffalo Bills 24.2    [30, 29, 17, 30, 15]
# 30        New York Giants 24.2    [7, 32, 30, 26, 26]
# 31        Oakland Raiders 24.2    [15, 28, 23, 25, 30]
# 32          New York Jets 25.0    [30, 11, 20, 32, 32]
#
# Defense:
#
#  1      Minnesota Vikings  4.2    [10, 5, 4, 1, 1]
#  2          Chicago Bears  6.4    [1, 6, 1, 3, 21]
#  3    Pittsburgh Steelers 10.4    [23, 1, 9, 6, 13]
#  4    Washington Redskins 11.0    [4, 14, 6, 26, 5]
#  5     Kansas City Chiefs 11.6    [4, 2, 20, 5, 27]
#  6       Baltimore Ravens 12.8    [27, 8, 3, 4, 22]
#  7       Seattle Seahawks 12.8    [10, 12, 17, 7, 18]
#  8          New York Jets 13.4    [10, 26, 21, 2, 8]
#  9   Los Angeles Chargers 13.8    [10, 15, 18, 22, 4]
# 10     Indianapolis Colts 14.0    [4, 16, 14, 27, 9]
# 11      Green Bay Packers 14.6    [23, 3, 26, 10, 11]
# 12    Philadelphia Eagles 14.6    [28, 17, 12, 9, 7]
# 13         Dallas Cowboys 15.2    [28, 11, 5, 29, 3]
# 14       Tennessee Titans 15.8    [23, 23, 11, 20, 2]
# 15         Denver Broncos 16.4    [10, 7, 27, 19, 19]
# 16      Arizona Cardinals 16.6    [23, 4, 30, 14, 12]
# 17     New Orleans Saints 16.6    [17, 21, 2, 15, 28]
# 18          Buffalo Bills 16.8    [19, 18, 10, 12, 25]
# 19      Carolina Panthers 16.8    [4, 24, 8, 17, 31]
# 20       Cleveland Browns 17.0    [3, 22, 28, 8, 24]
# 21         Houston Texans 17.0    [17, 10, 7, 21, 30]
# 22   Jacksonville Jaguars 17.6    [19, 27, 15, 13, 14]
# 23       Los Angeles Rams 18.0    [10, 9, 22, 23, 26]
# 24    San Francisco 49ers 18.0    [31, 19, 13, 11, 16]
# 25   New England Patriots 19.0    [4, 30, 16, 25, 20]
# 26         Miami Dolphins 19.8    [2, 29, 29, 24, 15]
# 27          Detroit Lions 20.0    [28, 13, 24, 18, 17]
# 28        New York Giants 20.4    [10, 31, 25, 30, 6]
# 29     Cincinnati Bengals 23.2    [4, 25, 32, 32, 23]
# 30   Tampa Bay Buccaneers 23.8    [32, 20, 19, 16, 32]
# 31        Oakland Raiders 24.6    [22, 32, 31, 28, 10]
# 32        Atlanta Falcons 26.0    [19, 28, 23, 31, 29]

# %%
for i in range(len(schedule)):
    if ( schedule[i][0]==wk and schedule[i][1]==' ' ) or schedule[i][0:2]==wk:
        
        team_away = schedule[i][3:29].lstrip().rstrip()
        team_home = schedule[i][28:].lstrip().rstrip()
        
        spread1 = 2.5 + (- data_dict[team_away]['SRS'] + data_dict[team_home]['SRS']) / 2.
        
        rnk_1 = data_dict[team_away]['interceptDEF'][1]
        col_1 = '30'
        if rnk_1 <= 8:
            col_1 = '32'
        elif rnk_1 >= 25:
            col_1 = '31'
        str_1 = str(rnk_1).rjust(3)
            
        rnk_2 = data_dict[team_home]['interceptDEF'][1]
        col_2 = '30'
        if rnk_2 <= 8:
            col_2 = '32'
        elif rnk_2 >= 25:
            col_2 = '31'
        str_2 = str(rnk_2).rjust(3)
        
        rnk_3 = data_dict[team_away]['interceptOFF'][1]
        col_3 = '30'
        if rnk_3 <= 8:
            col_3 = '32'
        elif rnk_3 >= 25:
            col_3 = '31'
        str_3 = str(rnk_3).rjust(3)
            
        rnk_4 = data_dict[team_home]['interceptOFF'][1]
        col_4 = '30'
        if rnk_4 <= 8:
            col_4 = '32'
        elif rnk_4 >= 25:
            col_4 = '31'
        str_4 = str(rnk_4).rjust(3)
        
        rnk_5 = data_dict[team_away]['timessacked'][1]
        col_5 = '30'
        if rnk_5 <= 8:
            col_5 = '32'
        elif rnk_5 >= 25:
            col_5 = '31'
        str_5 = str(rnk_5).rjust(3)
            
        rnk_6 = data_dict[team_home]['timessacked'][1]
        col_6 = '30'
        if rnk_6 <= 8:
            col_6 = '32'
        elif rnk_6 >= 25:
            col_6 = '31'
        str_6 = str(rnk_6).rjust(3)
        
        rnk_7 = data_dict[team_away]['sacks'][1]
        col_7 = '30'
        if rnk_7 <= 8:
            col_7 = '32'
        elif rnk_7 >= 25:
            col_7 = '31'
        str_7 = str(rnk_7).rjust(3)
            
        rnk_8 = data_dict[team_home]['sacks'][1]
        col_8 = '30'
        if rnk_8 <= 8:
            col_8 = '32'
        elif rnk_8 >= 25:
            col_8 = '31'
        str_8 = str(rnk_8).rjust(3)
        
        rnk_9 = data_dict[team_away]['rushOFF'][1]
        col_9 = '30'
        if rnk_9 <= 8:
            col_9 = '32'
        elif rnk_9 >= 25:
            col_9 = '31'
        str_9 = str(rnk_9).rjust(3)
            
        rnk_10 = data_dict[team_home]['rushOFF'][1]
        col_10 = '30'
        if rnk_10 <= 8:
            col_10 = '32'
        elif rnk_10 >= 25:
            col_10 = '31'
        str_10 = str(rnk_10).rjust(3)
        
        rnk_11 = data_dict[team_away]['rushDEF'][1]
        col_11 = '30'
        if rnk_11 <= 8:
            col_11 = '32'
        elif rnk_11 >= 25:
            col_11 = '31'
        str_11 = str(rnk_11).rjust(3)
            
        rnk_12 = data_dict[team_home]['rushDEF'][1]
        col_12 = '30'
        if rnk_12 <= 8:
            col_12 = '32'
        elif rnk_12 >= 25:
            col_12 = '31'
        str_12 = str(rnk_12).rjust(3)
        
        rnk_13 = data_dict[team_away]['3DconvOFF'][1]
        col_13 = '30'
        if rnk_13 <= 8:
            col_13 = '32'
        elif rnk_13 >= 25:
            col_13 = '31'
        str_13 = str(rnk_13).rjust(3)
            
        rnk_14 = data_dict[team_home]['3DconvOFF'][1]
        col_14 = '30'
        if rnk_14 <= 8:
            col_14 = '32'
        elif rnk_14 >= 25:
            col_14 = '31'
        str_14 = str(rnk_14).rjust(3)
        
        rnk_15 = data_dict[team_away]['3DconvDEF'][1]
        col_15 = '30'
        if rnk_15 <= 8:
            col_15 = '32'
        elif rnk_15 >= 25:
            col_15 = '31'
        str_15 = str(rnk_15).rjust(3)
            
        rnk_16 = data_dict[team_home]['3DconvDEF'][1]
        col_16 = '30'
        if rnk_16 <= 8:
            col_16 = '32'
        elif rnk_16 >= 25:
            col_16 = '31'
        str_16 = str(rnk_16).rjust(3)
        
        rnk_17 = data_dict[team_away]['redzoneOFF'][1]
        col_17 = '30'
        if rnk_17 <= 8:
            col_17 = '32'
        elif rnk_17 >= 25:
            col_17 = '31'
        str_17 = str(rnk_17).rjust(3)
            
        rnk_18 = data_dict[team_home]['redzoneOFF'][1]
        col_18 = '30'
        if rnk_18 <= 8:
            col_18 = '32'
        elif rnk_18 >= 25:
            col_18 = '31'
        str_18 = str(rnk_18).rjust(3)
        
        rnk_19 = data_dict[team_away]['redzoneDEF'][1]
        col_19 = '30'
        if rnk_19 <= 8:
            col_19 = '32'
        elif rnk_19 >= 25:
            col_19 = '31'
        str_19 = str(rnk_19).rjust(3)
            
        rnk_20 = data_dict[team_home]['redzoneDEF'][1]
        col_20 = '30'
        if rnk_20 <= 8:
            col_20 = '32'
        elif rnk_20 >= 25:
            col_20 = '31'
        str_20 = str(rnk_20).rjust(3)
        
        #OFF_away = np.mean([rnk_1, rnk_3, rnk_5, rnk_9, rnk_13, rnk_17])
        #OFF_home = np.mean([rnk_2, rnk_4, rnk_6, rnk_10, rnk_14, rnk_18])
        OFF_away = data_dict[team_away]['OFFENSE'][1]
        OFF_home = data_dict[team_home]['OFFENSE'][1]
        
        #DEF_away = np.mean([rnk_7, rnk_11, rnk_15, rnk_19])
        #DEF_home = np.mean([rnk_8, rnk_12, rnk_16, rnk_20])
        DEF_away = data_dict[team_away]['DEFENSE'][1]
        DEF_home = data_dict[team_home]['DEFENSE'][1]
        
        spread2 = 2.5 + (OFF_away - OFF_home)/2 + (DEF_away - DEF_home)/2
        
        spread = (spread1 + spread2) / 2
        #spread = spread1 
        
        #print(team_away.rjust(22) + ' {0:+5.1f} ({1:+5.1f}, {2:+5.1f})   at   '.format(spread, spread1, spread2) + team_home )
        print(team_away.rjust(22) + ' {0:+5.1f} ({1:+5.1f}, {2:+5.1f})    at   '.format(spread, spread1, spread2) + team_home )
        print()
        #print('penalties:  {0:3d}'.format(data_dict[team_away]['penalties'][1]).rjust(22))
        #colorpr2('penalties:        ', str_1, col_1, '         ', str_2, col_2)
        colorpr2('interceptOFF:     ', str_3, col_3, '   interceptDEF:', str_2, col_2)
        colorpr2('timessacked:      ', str_5, col_5, '   sacks:', str_8, col_8)
        colorpr2('rushOFF:          ', str_9, col_9, '   rushDEF:', str_12, col_12)
        colorpr2('3DconvOFF:        ', str_13, col_13, '   3DconvDEF:', str_16, col_16)
        colorpr2('redzoneOFF:       ', str_17, col_17, '   redzoneDEF:', str_20, col_20)
        print('----------------------------------------------------------')
        print('OFFENSE:             {0:3d} ({1:4.1f})'.format(data_dict[team_away]['OFFENSE'][0], data_dict[team_away]['OFFENSE'][1]), \
              '  DEFENSE:      {0:3d} ({1:4.1f})'.format(data_dict[team_home]['DEFENSE'][0], data_dict[team_home]['DEFENSE'][1]))
        print()
        colorpr2('interceptDEF:     ', str_1, col_1, '   interceptOFF:', str_4, col_4)
        colorpr2('sacks:            ', str_7, col_7, '   timessacked:', str_6, col_6)
        colorpr2('rushDEF:          ', str_11, col_11, '   rushOFF:', str_10, col_10)
        colorpr2('3DconvDEF:        ', str_15, col_15, '   3DconvOFF:', str_14, col_14)
        colorpr2('redzoneDEF:       ', str_19, col_19, '   redzoneOFF:', str_18, col_18)
        print('----------------------------------------------------------')
        print('DEFENSE:             {0:3d} ({1:4.1f})'.format(data_dict[team_away]['DEFENSE'][0], data_dict[team_away]['DEFENSE'][1]), \
              '  OFFENSE:      {0:3d} ({1:4.1f})'.format(data_dict[team_home]['OFFENSE'][0], data_dict[team_home]['OFFENSE'][1]))
        print()
        print()
# Out:
#          Chicago Bears  -6.2 ( -2.8,  -9.6)    at   Detroit Lions
#
# interceptOFF:         17        interceptDEF:    28
# timessacked:           6        sacks:           13
# rushOFF:              10        rushDEF:         24
# 3DconvOFF:            10        3DconvDEF:       18
# redzoneOFF:           12        redzoneDEF:      17
# ----------------------------------------------------------
# OFFENSE:               6 (11.0)   DEFENSE:       27 (20.0)
#
# interceptDEF:          1        interceptOFF:    17
# sacks:                 6        timessacked:     21
# rushDEF:               1        rushOFF:         24
# 3DconvDEF:             3        3DconvOFF:       21
# redzoneDEF:           21        redzoneOFF:      25
# ----------------------------------------------------------
# DEFENSE:               2 ( 6.4)   OFFENSE:       26 (21.6)
#
#
#    Washington Redskins  +0.9 ( +3.1,  -1.4)    at   Dallas Cowboys
#
# interceptOFF:          4        interceptDEF:    28
# timessacked:          12        sacks:           11
# rushOFF:              12        rushDEF:          5
# 3DconvOFF:            20        3DconvDEF:       29
# redzoneOFF:           20        redzoneDEF:       3
# ----------------------------------------------------------
# OFFENSE:              13 (13.6)   DEFENSE:       13 (15.2)
#
# interceptDEF:          4        interceptOFF:     4
# sacks:                14        timessacked:     30
# rushDEF:               6        rushOFF:          4
# 3DconvDEF:            26        3DconvOFF:       24
# redzoneDEF:            5        redzoneOFF:      24
# ----------------------------------------------------------
# DEFENSE:               4 (11.0)   OFFENSE:       17 (17.2)
#
#
#        Atlanta Falcons +10.8 (+10.0, +11.6)    at   New Orleans Saints
#
# interceptOFF:          3        interceptDEF:    17
# timessacked:          17        sacks:           21
# rushOFF:              29        rushDEF:          2
# 3DconvOFF:             2        3DconvDEF:       15
# redzoneOFF:            9        redzoneDEF:      28
# ----------------------------------------------------------
# OFFENSE:              10 (12.0)   DEFENSE:       17 (16.6)
#
# interceptDEF:         19        interceptOFF:     1
# sacks:                28        timessacked:      1
# rushDEF:              23        rushOFF:          6
# 3DconvDEF:            31        3DconvOFF:        5
# redzoneDEF:           29        redzoneOFF:       3
# ----------------------------------------------------------
# DEFENSE:              32 (26.0)   OFFENSE:        1 ( 3.2)
#
#
#        Oakland Raiders +13.8 (+12.3, +15.3)    at   Baltimore Ravens
#
# interceptOFF:         15        interceptDEF:    27
# timessacked:          28        sacks:            8
# rushOFF:              23        rushDEF:          3
# 3DconvOFF:            25        3DconvDEF:        4
# redzoneOFF:           30        redzoneDEF:      22
# ----------------------------------------------------------
# OFFENSE:              31 (24.2)   DEFENSE:        6 (12.8)
#
# interceptDEF:         22        interceptOFF:    11
# sacks:                32        timessacked:      7
# rushDEF:              31        rushOFF:         16
# 3DconvDEF:            28        3DconvOFF:        7
# redzoneDEF:           10        redzoneOFF:      11
# ----------------------------------------------------------
# DEFENSE:              31 (24.6)   OFFENSE:        5 (10.4)
#
#
#        New York Giants  +6.0 ( +3.8,  +8.2)    at   Philadelphia Eagles
#
# interceptOFF:          7        interceptDEF:    28
# timessacked:          32        sacks:           17
# rushOFF:              30        rushDEF:         12
# 3DconvOFF:            26        3DconvDEF:        9
# redzoneOFF:           26        redzoneDEF:       7
# ----------------------------------------------------------
# OFFENSE:              30 (24.2)   DEFENSE:       12 (14.6)
#
# interceptDEF:         10        interceptOFF:    11
# sacks:                31        timessacked:     23
# rushDEF:              25        rushOFF:         25
# 3DconvDEF:            30        3DconvOFF:       13
# redzoneDEF:            6        redzoneOFF:      21
# ----------------------------------------------------------
# DEFENSE:              28 (20.4)   OFFENSE:       19 (18.6)
#
#
#   Jacksonville Jaguars  -0.0 ( -0.4,  +0.3)    at   Buffalo Bills
#
# interceptOFF:         17        interceptDEF:    19
# timessacked:          20        sacks:           18
# rushOFF:              22        rushDEF:         10
# 3DconvOFF:             9        3DconvDEF:       12
# redzoneOFF:           27        redzoneDEF:      25
# ----------------------------------------------------------
# OFFENSE:              20 (19.0)   DEFENSE:       18 (16.8)
#
# interceptDEF:         19        interceptOFF:    30
# sacks:                27        timessacked:     29
# rushDEF:              15        rushOFF:         17
# 3DconvDEF:            13        3DconvOFF:       30
# redzoneDEF:           14        redzoneOFF:      15
# ----------------------------------------------------------
# DEFENSE:              22 (17.6)   OFFENSE:       29 (24.2)
#
#
#         Miami Dolphins  +9.9 ( +7.2, +12.5)    at   Indianapolis Colts
#
# interceptOFF:         17        interceptDEF:     4
# timessacked:          16        sacks:           16
# rushOFF:              21        rushDEF:         14
# 3DconvOFF:            28        3DconvDEF:       27
# redzoneOFF:           31        redzoneDEF:       9
# ----------------------------------------------------------
# OFFENSE:              27 (22.6)   DEFENSE:       10 (14.0)
#
# interceptDEF:          2        interceptOFF:    17
# sacks:                29        timessacked:      2
# rushDEF:              29        rushOFF:         14
# 3DconvDEF:            24        3DconvOFF:        1
# redzoneDEF:           15        redzoneOFF:       8
# ----------------------------------------------------------
# DEFENSE:              26 (19.8)   OFFENSE:        3 ( 8.4)
#
#
#   New England Patriots  -2.2 ( -3.0,  -1.4)    at   New York Jets
#
# interceptOFF:         11        interceptDEF:    10
# timessacked:           4        sacks:           26
# rushOFF:              19        rushDEF:         21
# 3DconvOFF:            14        3DconvDEF:        2
# redzoneOFF:           10        redzoneDEF:       8
# ----------------------------------------------------------
# OFFENSE:               8 (11.6)   DEFENSE:        8 (13.4)
#
# interceptDEF:          4        interceptOFF:    30
# sacks:                30        timessacked:     11
# rushDEF:              16        rushOFF:         20
# 3DconvDEF:            25        3DconvOFF:       32
# redzoneDEF:           20        redzoneOFF:      32
# ----------------------------------------------------------
# DEFENSE:              25 (19.0)   OFFENSE:       32 (25.0)
#
#
#       Cleveland Browns  +2.2 ( +2.6,  +1.7)    at   Cincinnati Bengals
#
# interceptOFF:         23        interceptDEF:     4
# timessacked:          31        sacks:           25
# rushOFF:               5        rushDEF:         32
# 3DconvOFF:            29        3DconvDEF:       32
# redzoneOFF:           13        redzoneDEF:      23
# ----------------------------------------------------------
# OFFENSE:              24 (20.2)   DEFENSE:       29 (23.2)
#
# interceptDEF:          3        interceptOFF:    23
# sacks:                22        timessacked:     10
# rushDEF:              28        rushOFF:         28
# 3DconvDEF:             8        3DconvOFF:       16
# redzoneDEF:           24        redzoneOFF:       1
# ----------------------------------------------------------
# DEFENSE:              20 (17.0)   OFFENSE:       14 (15.6)
#
#
#       Seattle Seahawks  +1.6 ( +0.7,  +2.5)    at   Carolina Panthers
#
# interceptOFF:          4        interceptDEF:     4
# timessacked:          24        sacks:           24
# rushOFF:               1        rushDEF:          8
# 3DconvOFF:            22        3DconvDEF:       17
# redzoneOFF:            7        redzoneDEF:      31
# ----------------------------------------------------------
# OFFENSE:               9 (11.6)   DEFENSE:       19 (16.8)
#
# interceptDEF:         10        interceptOFF:     7
# sacks:                12        timessacked:      8
# rushDEF:              17        rushOFF:          7
# 3DconvDEF:             7        3DconvOFF:       12
# redzoneDEF:           18        redzoneOFF:       4
# ----------------------------------------------------------
# DEFENSE:               7 (12.8)   OFFENSE:        2 ( 7.6)
#
#
#    San Francisco 49ers  +1.2 ( +3.0,  -0.5)    at   Tampa Bay Buccaneers
#
# interceptOFF:         28        interceptDEF:    32
# timessacked:          22        sacks:           20
# rushOFF:               3        rushDEF:         19
# 3DconvOFF:            15        3DconvDEF:       16
# redzoneOFF:           28        redzoneDEF:      32
# ----------------------------------------------------------
# OFFENSE:              21 (19.2)   DEFENSE:       30 (23.8)
#
# interceptDEF:         31        interceptOFF:    32
# sacks:                19        timessacked:     18
# rushDEF:              13        rushOFF:         27
# 3DconvDEF:            11        3DconvOFF:        3
# redzoneDEF:           16        redzoneOFF:      17
# ----------------------------------------------------------
# DEFENSE:              24 (18.0)   OFFENSE:       23 (19.4)
#
#
#      Arizona Cardinals  +9.2 ( +9.2,  +9.2)    at   Los Angeles Chargers
#
# interceptOFF:         29        interceptDEF:    10
# timessacked:          19        sacks:           15
# rushOFF:              32        rushDEF:         18
# 3DconvOFF:            31        3DconvDEF:       22
# redzoneOFF:            5        redzoneDEF:       4
# ----------------------------------------------------------
# OFFENSE:              28 (23.2)   DEFENSE:        9 (13.8)
#
# interceptDEF:         23        interceptOFF:     7
# sacks:                 4        timessacked:      5
# rushDEF:              30        rushOFF:          9
# 3DconvDEF:            14        3DconvOFF:       23
# redzoneDEF:           12        redzoneOFF:      19
# ----------------------------------------------------------
# DEFENSE:              16 (16.6)   OFFENSE:       12 (12.6)
#
#
#    Pittsburgh Steelers  -2.5 ( -1.1,  -3.8)    at   Denver Broncos
#
# interceptOFF:         23        interceptDEF:    10
# timessacked:           3        sacks:            7
# rushOFF:              26        rushDEF:         27
# 3DconvOFF:             6        3DconvDEF:       19
# redzoneOFF:            2        redzoneDEF:      19
# ----------------------------------------------------------
# OFFENSE:              11 (12.0)   DEFENSE:       15 (16.4)
#
# interceptDEF:         23        interceptOFF:    23
# sacks:                 1        timessacked:     13
# rushDEF:               9        rushOFF:          8
# 3DconvDEF:             6        3DconvOFF:       27
# redzoneDEF:           13        redzoneOFF:      22
# ----------------------------------------------------------
# DEFENSE:               3 (10.4)   OFFENSE:       18 (18.6)
#
#
#      Green Bay Packers  +4.2 ( +2.7,  +5.8)    at   Minnesota Vikings
#
# interceptOFF:          2        interceptDEF:    10
# timessacked:          25        sacks:            5
# rushOFF:              18        rushDEF:          4
# 3DconvOFF:            19        3DconvDEF:        1
# redzoneOFF:           14        redzoneDEF:       1
# ----------------------------------------------------------
# OFFENSE:              15 (15.6)   DEFENSE:        1 ( 4.2)
#
# interceptDEF:         23        interceptOFF:    11
# sacks:                 3        timessacked:     15
# rushDEF:              26        rushOFF:         31
# 3DconvDEF:            10        3DconvOFF:       17
# redzoneDEF:           11        redzoneOFF:      23
# ----------------------------------------------------------
# DEFENSE:              11 (14.6)   OFFENSE:       22 (19.4)
#
#
#       Tennessee Titans  +2.1 ( +4.0,  +0.2)    at   Houston Texans
#
# interceptOFF:         15        interceptDEF:    17
# timessacked:          26        sacks:           10
# rushOFF:              15        rushDEF:          7
# 3DconvOFF:            11        3DconvDEF:       21
# redzoneOFF:           18        redzoneDEF:      30
# ----------------------------------------------------------
# OFFENSE:              16 (17.0)   DEFENSE:       21 (17.0)
#
# interceptDEF:         23        interceptOFF:    17
# sacks:                23        timessacked:     27
# rushDEF:              11        rushOFF:         11
# 3DconvDEF:            20        3DconvOFF:       18
# redzoneDEF:            2        redzoneOFF:      29
# ----------------------------------------------------------
# DEFENSE:              14 (15.8)   OFFENSE:       25 (20.4)
